# %%
#Path related stuff
import os

#Math stuff
import numpy as np
import random

#Environment stuff
import gym
import mujoco_py

#3D Object stuff
import pyvista as pv

#Pytorch Stuff 
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal
import torch.nn.functional as F
from torch.optim import Adam
from torch.optim import NAdam

#To import other notebooks
import import_ipynb

#Matplotlib stuff
#import matplotlib.pyplot as plt
#Helper class imports
from Helper_class2 import ThreeD_Obstacle
from Helper_class2 import Features
from Helper_class2 import AgentUtils

# %%
class ReplayBuffer:
  def __init__(self, buffer_size, batch_size, seed = 4):
    self.buffer = []
    self.max_size = buffer_size
    self.batch_size = batch_size
    self.random_generator = np.random.RandomState(seed)

  def append(self, state, action, reward, terminal, next_state, cost):
    if(len(self.buffer) == self.max_size):
      del self.buffer[0]

    self.buffer.append([state, action, reward, terminal, next_state, cost])

  def sample(self):
    batch = random.sample(self.buffer, self.batch_size)

    state, action, reward, terminal, next_state, cost = map(np.stack, zip(*batch))
    
    return state, action, reward, terminal, next_state, cost

  def get_buffer_size(self):
    return len(self.buffer)

# %%
LOG_SIG_MAX = 2
LOG_SIG_MIN = -20
epsilon = 1e-6

#Initialize Policy weights
def weights_init_(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight, gain=1)
        torch.nn.init.constant_(m.bias, 0)

class QNetwork(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_dim):
        super(QNetwork, self).__init__()
        
        # Q1 architecture
        self.linear1 = nn.Linear(num_inputs + num_actions, hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, hidden_dim)
        self.linear3 = nn.Linear(hidden_dim, hidden_dim)
        self.linear4 = nn.Linear(hidden_dim, 1)

        # Q2 architecture
        self.linear5 = nn.Linear(num_inputs + num_actions, hidden_dim)
        self.linear6 = nn.Linear(hidden_dim, hidden_dim)
        self.linear7 = nn.Linear(hidden_dim, hidden_dim)
        self.linear8 = nn.Linear(hidden_dim, 1)

        self.apply(weights_init_)

    def forward(self, state, action):
        xu = torch.cat([state, action], 1)
        
        x1 = F.relu(self.linear1(xu))
        x1 = F.relu(self.linear2(x1))
        x1 = F.relu(self.linear3(x1))
        
        x1 = self.linear4(x1)

        x2 = F.relu(self.linear5(xu))
        x2 = F.relu(self.linear6(x2))
        x2 = F.relu(self.linear7(x2))
        x2 = self.linear8(x2)

        return x1, x2


class GaussianPolicy(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_dim, action_range=None):
        super(GaussianPolicy, self).__init__()
        
        self.linear1 = nn.Linear(num_inputs, hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, hidden_dim)
        self.linear3 = nn.Linear(hidden_dim, hidden_dim)

        self.mean_linear = nn.Linear(hidden_dim, num_actions)
        self.log_std_linear = nn.Linear(hidden_dim, num_actions)

        self.apply(weights_init_)

        # action rescaling
        if action_range is None:
            self.action_scale = torch.tensor(1.)
            self.action_bias = torch.tensor(0.)
        else:
            self.action_scale = torch.FloatTensor([
                (np.max(action_range) - np.min(action_range)) / 2.
                ])
            self.action_bias = torch.FloatTensor([
                (np.max(action_range) - np.max(action_range)) / 2.
                ])

    def forward(self, state):
        x = F.relu(self.linear1(state))
        x = F.relu(self.linear2(x))
        x = F.relu(self.linear3(x))

        mean = self.mean_linear(x)
        log_std = self.log_std_linear(x)
        log_std = torch.clamp(log_std, min=LOG_SIG_MIN, max=LOG_SIG_MAX)
        return mean, log_std

    def sample(self, state):
        mean, log_std = self.forward(state)
        std = log_std.exp()
        normal = Normal(mean, std)
        x_t = normal.rsample()  # for reparameterization trick (mean + std * N(0,1))
        y_t = torch.tanh(x_t)
        action = y_t * self.action_scale + self.action_bias
        log_prob = normal.log_prob(x_t)
        # Enforcing Action Bound
        log_prob -= torch.log(self.action_scale * (1 - y_t.pow(2)) + epsilon)
        log_prob = log_prob.sum(1, keepdim=True)
        
        mean = torch.tanh(mean) * self.action_scale + self.action_bias
        return action, log_prob, mean

    def to(self, device):
        self.action_scale = self.action_scale.to(device)
        self.action_bias = self.action_bias.to(device)
        return super(GaussianPolicy, self).to(device)

# %%
class SAC_Agent(object):
    def __init__(self,observation_space, action_space, gamma, lr,  tau, alpha, hidden_network_size, 
                 action_range, batch_size, agent_util):
        self.agent_util = agent_util

        self.REPLAY_BATCH_SIZE = batch_size
        self.replay_buffer = ReplayBuffer(300000, self.REPLAY_BATCH_SIZE)

        self.gamma = gamma
        self.lr = lr
        self.tau = tau
        self.alpha = alpha

        self.device = "cuda:0" if torch.cuda.is_available() else "cpu"
        
        self.LEARNING_RATE_LAM = 0.001
        self.lamb = torch.tensor(-10.0, requires_grad=True, device=self.device)
        self.lamb_optimiser = torch.optim.Adam([self.lamb], lr=self.LEARNING_RATE_LAM, weight_decay=1e-5)

        self.cost_lim = 0.001

        self.iterator = 1

        self.critic = QNetwork(observation_space[0], action_space[0], hidden_network_size).to(device=self.device)
        self.critic_optim = Adam(self.critic.parameters(), lr=self.lr)

        self.critic_target = QNetwork(observation_space[0], action_space[0], hidden_network_size).to(self.device)
        

        self.critic_cost = QNetwork(observation_space[0], action_space[0], hidden_network_size).to(device=self.device)
        self.critic_cost_optim = Adam(self.critic_cost.parameters(), lr=self.lr)
        
        self.critic_target_cost = QNetwork(observation_space[0], action_space[0], hidden_network_size).to(self.device)
        
        #perfoming a soft copy of the parameters
        for target_param, param in zip( self.critic_target.parameters(), self.critic.parameters()):
            target_param.data.copy_( param.data * self.tau + (1-self.tau) * target_param.data)

        for target_param, param in zip( self.critic_target_cost.parameters(), self.critic_cost.parameters()):
            target_param.data.copy_( param.data * self.tau + (1-self.tau) * target_param.data)


        self.policy = GaussianPolicy(observation_space[0], action_space[0], hidden_network_size, action_range).to(self.device)
        self.policy_optim = Adam(self.policy.parameters(), lr=self.lr)


        # self.target_entropy = -torch.prod(torch.Tensor(action_space).to(self.device)).item()
        # self.log_alpha = torch.zeros(1, requires_grad=True, device=self.device)
        # self.alpha_optim = NAdam([self.log_alpha], lr=self.lr)


    def select_action(self, state, evaluate=False):
        state = torch.FloatTensor(state).to(self.device).unsqueeze(0)
        if evaluate is False:
            action, _, _ = self.policy.sample(state)

        return action.detach().cpu().numpy()[0]
    
    
    def gradient_clipping(self, model_parameters, clip_val):
        torch.nn.utils.clip_grad_norm_(model_parameters, max_norm=clip_val, norm_type=2)

    
    def update_parameters(self):
        # Sample a batch from memory

        state_batch, action_batch, reward_batch, mask_batch, next_state_batch, cost_batch = self.replay_buffer.sample()

        state_batch = torch.FloatTensor(state_batch).to(self.device)
        next_state_batch = torch.FloatTensor(next_state_batch).to(self.device)
        action_batch = torch.FloatTensor(action_batch).to(self.device)
        reward_batch = torch.FloatTensor(reward_batch).to(self.device).unsqueeze(1)
        mask_batch = torch.FloatTensor(mask_batch).to(self.device).unsqueeze(1)
        cost_batch = torch.FloatTensor(cost_batch).to(self.device).unsqueeze(1)

        with torch.no_grad():
            next_state_action, next_state_log_pi, _ = self.policy.sample(next_state_batch)
            
            qf1_next_target, qf2_next_target = self.critic_target(next_state_batch, next_state_action)
            min_qf_next_target = torch.min(qf1_next_target, qf2_next_target) - self.alpha * next_state_log_pi
            next_q_value = (reward_batch) + (1-mask_batch) * self.gamma * (min_qf_next_target)

            qf1_next_target_cost, _ = self.critic_target_cost(next_state_batch, next_state_action)
            #min_qf_next_target_cost = torch.min(qf1_next_target_cost, qf2_next_target_cost)
            next_q_value_cost = cost_batch + (1-mask_batch) * self.gamma * (qf1_next_target_cost)
       

        qf1, qf2 = self.critic(state_batch, action_batch) # Two Q-functions to mitigate positive bias in the policy improvement step
        qf1_c, _ = self.critic_cost(state_batch, action_batch) # Two Q-functions to mitigate positive bias in the policy improvement step

        qf1_loss = F.mse_loss(qf1, next_q_value)
        qf2_loss = F.mse_loss(qf2, next_q_value)

        qf1_cost_loss = F.mse_loss(qf1_c, next_q_value_cost)  # JQ = 𝔼(st,at)~D[0.5(Q1(st,at) - r(st,at) - γ(𝔼st+1~p[V(st+1)]))^2]


        qf_loss = (qf1_loss + qf2_loss).mean()
        qf_cost_loss = qf1_cost_loss.mean()


        self.critic_optim.zero_grad()
        qf_loss.backward()
        self.critic_optim.step()

        self.critic_cost_optim.zero_grad()
        qf_cost_loss.backward()
        self.critic_cost_optim.step()


        for target_param, param in zip( self.critic_target.parameters(), self.critic.parameters()):
            target_param.data.copy_( param.data * self.tau + (1-self.tau) * target_param.data)
        
        for target_param, param in zip( self.critic_target_cost.parameters(), self.critic_cost.parameters()):
            target_param.data.copy_( param.data * self.tau + (1-self.tau) * target_param.data)


        pi, log_pi, _ = self.policy.sample(state_batch)
        

        qf1_pi, qf2_pi = self.critic(state_batch, pi)
        min_qf_pi = torch.min(qf1_pi, qf2_pi)
        first_term = (self.alpha * log_pi) - min_qf_pi

        qf1_pi_c, _ = self.critic_cost(state_batch, pi)
        
        second_term = 10*self.lamb * qf1_pi_c

        policy_loss = (first_term + second_term).mean()# Jπ = 𝔼st∼D,εt∼N[α * logπ(f(εt;st)|st) − Q(st,f(εt;st))]


        self.policy_optim.zero_grad()
        policy_loss.backward()
        self.policy_optim.step()


        #Training lambda
        #Training lambda
        self.iterator += 1
        
        if self.iterator % 3 == 0:

            violation = cost_batch - self.cost_lim
            
            self.log_lam = torch.nn.functional.softplus(self.lamb, beta=0.5)
            lambda_loss = -self.log_lam*(violation).detach()
            lambda_loss = lambda_loss.sum()

            self.lamb_optimiser.zero_grad()
            lambda_loss.backward()
            self.lamb_optimiser.step()

            self.iterator = 1

        
        return qf1_loss.item(), qf2_loss.item(), policy_loss.item()

# %%
mj_path = mujoco_py.utils.discover_mujoco()
xml_path = os.path.join(mj_path, 'model', 'ur5.xml')
model = mujoco_py.load_model_from_path(xml_path)
sim = mujoco_py.MjSim(model)
viewer = mujoco_py.MjRenderContextOffscreen(sim, -1)

##agent.critic.state_dict()

# %%
def models_performance_tracker(seed, network_size, q1_avg_loss, q2_avg_loss, policy_avg_loss, avg_reward, steps, crashes, total_violations, PATH):
    torch.save({
            'seed': seed,
            'network_size': network_size,
            'q1_avg_loss': q1_avg_loss,
            'q2_avg_loss': q2_avg_loss,
            'policy_avg_loss': policy_avg_loss,
            'avg_reward': avg_reward,
            'steps': steps,
            'crashes': crashes,
            'violations': total_violations,
            #'model_state_dict': agent.critic.state_dict(),
            #'optimizer_state_dict': optimizer.state_dict(),
            }, PATH)

# %%
EPOCHS = 10000
TARGET_POS = [-0.11034687, -0.59504954, 0.2978785 ] #based on [0, -0.22, 1.67, 0.66, 1.57, 0.22]

SEEDs = [0]
NETWORKs_SEARCH = [128] #This was 128 with seed 4,5 when it was working

#Object stuff
object_position1 = [-0.11034687, -0.59504954, 0.2978785 + 0.2] #the plus is the axis radius, to be on the same plne

# layer1_shere_semi_axis = [0.17,0.17,0.17]
# layer2_shere_semi_axis = [0.35,0.35,0.35]
l1_radius = 0.35
l2_radius = 0.34

threeD_object1 = ThreeD_Obstacle(simulation = sim, sphere_or_ellipsoid= "Sphere", 
                                 radius_or_axis = 0.2 , my_position = object_position1,
                                 safety_l1 = l1_radius,
                                 safety_l2 = l2_radius,
                                 target_pos = TARGET_POS,
                                   translation_rate= [0.008, 0, 0])

initial_action = [-2.42, -1.57, -0.597, -1.48, 3.14, -1.42]

#Arm stuff
arm_utils = AgentUtils(sim, threeD_object1, initial_action, TARGET_POS) 
arm_feature_object = Features(sim, threeD_object1, arm_utils)

for seed in SEEDs:
    alpha = 0.05
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    for network in NETWORKs_SEARCH:

        agent = SAC_Agent((48,), (6,), 0.99, 0.0001, 0.005, alpha, network, 
                          [-0.0698132, 0.0698132], 256, arm_utils)
        
        q1_loss_avgs = np.array([])
        q2_loss_avgs = np.array([])
        policy_loss_avgs = np.array([])
        average_rewards = np.array([])
        steps = np.array([])
        crashes = np.array([])
        total_violations = np.array([])
        lambda_episodes = []
        for i in range(EPOCHS):
            done = 0
            distance = 0
            step = 1
            minus_on_reward = 0
            
            #storing data
            q1_loss = np.array([])
            q2_loss = np.array([])
            policy_loss = np.array([])
            rewards = np.array([])
            violations = np.array([])
            crashed = 0

            #taking the initial step
            sim.data.qpos[:] = initial_action
            sim.step()

            #Getting features of the arm robot.
            calculated_features = arm_feature_object.get_all_features().copy()
            observation = calculated_features
            
            lambda_step = []
            
            time_step_T = 5000
            for _ in range(time_step_T):
                
                action = agent.select_action(observation).copy()
                
                # current_qpos = sim.data.qpos.copy()
                # new_qpos = current_qpos + action
                sim.data.qpos[:] = arm_utils.get_joint_angles(action)


                try:
                    sim.step()
                except mujoco_py.MujocoException as e:
                    if "Got MuJoCo Warning: Nan, Inf or huge value in QACC" in str(e):
                        print("Simulation is unstable. Taking corrective action...")
                        # Do something to correct the instability, e.g. reset the simulation or adjust the control parameters
                        sim.data.qpos[:] = [-2.42, -1.57, -0.597, -1.48, 3.14, -1.41]
                        sim.step() #required to update the joints and EE
                    else:
                        # Handle other MujocoExceptions as needed
                        print(f"Unexpected MujocoException: {e}")

              
                cost = threeD_object1.compute_link_distance_to_object_when_in_l1_by_closest_points_for_cost()
                violations = np.append(violations,cost)
                
                if( threeD_object1.object_intruded().sum() >= 1):
                    done = 1
                    crashed = 1
                    #max_distance_cost = np.abs(rewards).sum()
                    #threeD_object1.reset()

                    print("crashed")

                reward = arm_utils.get_reward()

                #translate the object
                threeD_object1.linearly_translate_object_back_and_forward()

                #Getting features of the arm robot.
                calculated_features = arm_feature_object.get_all_features().copy()
                new_observation = calculated_features

                if(arm_utils.check_EE_is_in_the_target_area() == 1):#function returns a 1 if the EE coordinates are in the sphere, else 0
                    done = 1

                rewards = np.append(rewards,reward)
                

                agent.replay_buffer.append(observation, action, reward, done, new_observation, cost)
                

                observation = new_observation

                if( agent.replay_buffer.get_buffer_size() > agent.REPLAY_BATCH_SIZE ):
                    q1_l, q2_l, policy_l = agent.update_parameters()

                    q1_loss = np.append(q1_loss, q1_l)
                    q2_loss = np.append(q2_loss, q2_l)
                    policy_loss = np.append(policy_loss, policy_l)
                   

                if(done == 1):
                    arm_utils = AgentUtils(sim, threeD_object1, initial_action, TARGET_POS) #resetting the object for the initial position
                    break
                
                step+=1

            print("epoch: ", i, ",  step : ",step, ",  avg_reward : ", rewards.mean())

            q1_loss_avgs = np.append(q1_loss_avgs, q1_loss.mean())
            q2_loss_avgs = np.append(q2_loss_avgs, q2_loss.mean())
            policy_loss_avgs = np.append(policy_loss_avgs, policy_loss.mean())
            average_rewards = np.append(average_rewards, rewards.mean())
            steps = np.append(steps, step)
            crashes = np.append(crashes,crashed)
            total_violations = np.append(total_violations,violations.sum())
            
            

        name = "FinalNonScalarizedLagrange_alpha="+str(alpha) +"_cost=0.001_seed=:"+str(seed)+".pt"
        Path = "/home/padjei/Desktop/Models/Reviewers/" + name  
        
        models_performance_tracker(seed=seed, network_size=network, q1_avg_loss=q1_loss_avgs, q2_avg_loss=q2_loss_avgs, 
                                   policy_avg_loss=policy_loss_avgs, avg_reward = average_rewards, steps=steps, crashes=crashes, 
                                    total_violations=total_violations, PATH=Path)
# Out:
# crashed
# epoch:  0 ,  step :  415 ,  avg_reward :  -1.0690160249010614
# Simulation is unstable. Taking corrective action...
# crashed
# epoch:  1 ,  step :  418 ,  avg_reward :  -0.8570927682444327
# crashed
# epoch:  2 ,  step :  3112 ,  avg_reward :  -0.7832154729588328
# epoch:  3 ,  step :  5001 ,  avg_reward :  -0.7884148356847998
# epoch:  4 ,  step :  5001 ,  avg_reward :  -0.8200029931831372
# epoch:  5 ,  step :  5001 ,  avg_reward :  -0.8337648318684553
# epoch:  6 ,  step :  5001 ,  avg_reward :  -0.7414235195631413
# intersected
# epoch:  7 ,  step :  1566 ,  avg_reward :  -0.9423474694294358
# crashed
# epoch:  8 ,  step :  1711 ,  avg_reward :  -0.8463263661195726
# crashed
# epoch:  9 ,  step :  1738 ,  avg_reward :  -0.8285121302921565
# crashed
# epoch:  10 ,  step :  2334 ,  avg_reward :  -0.8003291637342239
# intersected
# epoch:  11 ,  step :  672 ,  avg_reward :  -0.9347289757363352
# intersected
# epoch:  12 ,  step :  576 ,  avg_reward :  -0.9788792618122003
# crashed
# epoch:  13 ,  step :  3202 ,  avg_reward :  -0.9019065778272294
# intersected
# epoch:  14 ,  step :  284 ,  avg_reward :  -1.0621180238133996
# crashed
# epoch:  15 ,  step :  3639 ,  avg_reward :  -0.809470129045009
# crashed
# epoch:  16 ,  step :  4440 ,  avg_reward :  -0.8643693403292445
# epoch:  17 ,  step :  5001 ,  avg_reward :  -0.859917565861922
# crashed
# epoch:  18 ,  step :  167 ,  avg_reward :  -0.6961518629723593
# crashed
# epoch:  19 ,  step :  2938 ,  avg_reward :  -0.875983615677063
# crashed
# epoch:  20 ,  step :  3974 ,  avg_reward :  -0.81238540932794
# epoch:  21 ,  step :  5001 ,  avg_reward :  -0.8961193408230774
# crashed
# epoch:  22 ,  step :  2602 ,  avg_reward :  -0.7878571317511741
# crashed
# epoch:  23 ,  step :  370 ,  avg_reward :  -0.7845419446362691
# epoch:  24 ,  step :  5001 ,  avg_reward :  -0.967533947818692
# crashed
# epoch:  25 ,  step :  1872 ,  avg_reward :  -0.7904104548991077
# epoch:  26 ,  step :  5001 ,  avg_reward :  -0.8572445651370264
# epoch:  27 ,  step :  5001 ,  avg_reward :  -0.8291495301062216
# crashed
# epoch:  28 ,  step :  3126 ,  avg_reward :  -0.8990858539202324
# crashed
# epoch:  29 ,  step :  2016 ,  avg_reward :  -0.8504403186461411
# crashed
# epoch:  30 ,  step :  76 ,  avg_reward :  -0.8695601267740344
# crashed
# epoch:  31 ,  step :  57 ,  avg_reward :  -1.001154133421763
# intersected
# epoch:  32 ,  step :  66 ,  avg_reward :  -0.7261799435810457
# epoch:  33 ,  step :  5001 ,  avg_reward :  -0.7474753583236728
# intersected
# epoch:  34 ,  step :  3353 ,  avg_reward :  -0.789926368471184
# epoch:  35 ,  step :  5001 ,  avg_reward :  -0.8034160797545934
# intersected
# epoch:  36 ,  step :  311 ,  avg_reward :  -0.7828280723009838
# epoch:  37 ,  step :  5001 ,  avg_reward :  -0.776004190460382
# crashed
# epoch:  38 ,  step :  2067 ,  avg_reward :  -0.8366080544686243
# crashed
# epoch:  39 ,  step :  3168 ,  avg_reward :  -0.8063687776495807
# intersected
# epoch:  40 ,  step :  806 ,  avg_reward :  -0.8364344937916102
# intersected
# epoch:  41 ,  step :  677 ,  avg_reward :  -0.8348379501913548
# crashed
# epoch:  42 ,  step :  227 ,  avg_reward :  -0.8198185238865461
# crashed
# epoch:  43 ,  step :  1111 ,  avg_reward :  -0.7080284432711185
# intersected
# epoch:  44 ,  step :  1798 ,  avg_reward :  -0.828602275940712
# intersected
# epoch:  45 ,  step :  62 ,  avg_reward :  -0.8034960790397169
# intersected
# epoch:  46 ,  step :  669 ,  avg_reward :  -0.776059583093642
# crashed
# epoch:  47 ,  step :  212 ,  avg_reward :  -0.8970935364311529
# crashed
# epoch:  48 ,  step :  63 ,  avg_reward :  -0.8131504696295968
# crashed
# epoch:  49 ,  step :  738 ,  avg_reward :  -0.778083022710603
# crashed
# epoch:  50 ,  step :  36 ,  avg_reward :  -0.812164172916293
# crashed
# epoch:  51 ,  step :  479 ,  avg_reward :  -0.7678714002683604
# crashed
# epoch:  52 ,  step :  314 ,  avg_reward :  -0.711624285786158
# crashed
# epoch:  53 ,  step :  35 ,  avg_reward :  -0.9054184703827671
# crashed
# epoch:  54 ,  step :  2872 ,  avg_reward :  -0.8299136203808094
# crashed
# epoch:  55 ,  step :  1922 ,  avg_reward :  -0.7773874175496738
# crashed
# epoch:  56 ,  step :  483 ,  avg_reward :  -0.8436078596200788
# epoch:  57 ,  step :  5001 ,  avg_reward :  -0.8581048856040799
# crashed
# epoch:  58 ,  step :  1795 ,  avg_reward :  -0.8040271677864769
# intersected
# epoch:  59 ,  step :  752 ,  avg_reward :  -0.7507917691212656
# intersected
# epoch:  60 ,  step :  4506 ,  avg_reward :  -0.7853063638468449
# intersected
# epoch:  61 ,  step :  1110 ,  avg_reward :  -0.9558283928912563
# intersected
# epoch:  62 ,  step :  357 ,  avg_reward :  -0.8370626422170016
# crashed
# epoch:  63 ,  step :  935 ,  avg_reward :  -0.9082800777633645
# intersected
# epoch:  64 ,  step :  192 ,  avg_reward :  -0.8689750303440512
# crashed
# epoch:  65 ,  step :  90 ,  avg_reward :  -0.7540059873351684
# epoch:  66 ,  step :  5001 ,  avg_reward :  -0.8755454832282219
# crashed
# epoch:  67 ,  step :  614 ,  avg_reward :  -0.7346401919488006
# crashed
# epoch:  68 ,  step :  2025 ,  avg_reward :  -0.8274565545916884
# intersected
# epoch:  69 ,  step :  712 ,  avg_reward :  -0.5914938281006025
# crashed
# epoch:  70 ,  step :  1358 ,  avg_reward :  -0.6819990630254161
# intersected
# epoch:  71 ,  step :  296 ,  avg_reward :  -0.47166106954913245
# intersected
# epoch:  72 ,  step :  133 ,  avg_reward :  -0.47645895887798134
# intersected
# epoch:  73 ,  step :  1280 ,  avg_reward :  -0.9201898121270249
# intersected
# epoch:  74 ,  step :  1569 ,  avg_reward :  -0.8081047346603819
# crashed
# epoch:  75 ,  step :  654 ,  avg_reward :  -0.5377811705354442
# crashed
# epoch:  76 ,  step :  83 ,  avg_reward :  -0.832937002740929
# intersected
# epoch:  77 ,  step :  4113 ,  avg_reward :  -0.747986820058074
# intersected
# epoch:  78 ,  step :  479 ,  avg_reward :  -0.6095647827569434
# crashed
# epoch:  79 ,  step :  106 ,  avg_reward :  -0.697593838825327
# intersected
# epoch:  80 ,  step :  661 ,  avg_reward :  -0.7299518524785013
# intersected
# epoch:  81 ,  step :  939 ,  avg_reward :  -0.7843763029578111
# crashed
# epoch:  82 ,  step :  1218 ,  avg_reward :  -0.8286755657796943
# crashed
# epoch:  83 ,  step :  803 ,  avg_reward :  -0.7356324535654937
# crashed
# epoch:  84 ,  step :  4147 ,  avg_reward :  -0.8447530897727327
# crashed
# epoch:  85 ,  step :  1037 ,  avg_reward :  -0.6998762789977994
# intersected
# epoch:  86 ,  step :  2562 ,  avg_reward :  -0.8031051594244842
# intersected
# epoch:  87 ,  step :  181 ,  avg_reward :  -0.5927364192910505
# crashed
# epoch:  88 ,  step :  550 ,  avg_reward :  -0.8780872166272877
# intersected
# epoch:  89 ,  step :  887 ,  avg_reward :  -0.8090449185543299
# intersected
# epoch:  90 ,  step :  1466 ,  avg_reward :  -0.7182690214300949
# intersected
# epoch:  91 ,  step :  1357 ,  avg_reward :  -0.746234794579593
# crashed
# epoch:  92 ,  step :  637 ,  avg_reward :  -0.8592673060706011
# crashed
# epoch:  93 ,  step :  1229 ,  avg_reward :  -0.6825224347277487
# crashed
# epoch:  94 ,  step :  1175 ,  avg_reward :  -0.7178633306596912
# intersected
# epoch:  95 ,  step :  321 ,  avg_reward :  -0.6284121164663604
# crashed
# epoch:  96 ,  step :  592 ,  avg_reward :  -0.7217025240762005
# intersected
# epoch:  97 ,  step :  283 ,  avg_reward :  -0.7738063991787303
# crashed
# epoch:  98 ,  step :  498 ,  avg_reward :  -0.6261192012780836
# intersected
# epoch:  99 ,  step :  308 ,  avg_reward :  -0.6999626113990223
# crashed
# epoch:  100 ,  step :  2495 ,  avg_reward :  -0.7974825841801048
# intersected
# epoch:  101 ,  step :  1077 ,  avg_reward :  -0.7764943995445038
# crashed
# epoch:  102 ,  step :  32 ,  avg_reward :  -0.8387631979693653
# crashed
# epoch:  103 ,  step :  30 ,  avg_reward :  -0.7974381016183651
# intersected
# epoch:  104 ,  step :  180 ,  avg_reward :  -0.41540249681165636
# crashed
# epoch:  105 ,  step :  280 ,  avg_reward :  -0.7761597936297493
# crashed
# epoch:  106 ,  step :  760 ,  avg_reward :  -0.7531177731248533
# crashed
# epoch:  107 ,  step :  821 ,  avg_reward :  -0.8352278175897402
# crashed
# epoch:  108 ,  step :  42 ,  avg_reward :  -0.7080955439028801
# crashed
# epoch:  109 ,  step :  39 ,  avg_reward :  -0.7886422199343087
# intersected
# epoch:  110 ,  step :  478 ,  avg_reward :  -0.46486953341642884
# crashed
# epoch:  111 ,  step :  295 ,  avg_reward :  -0.643531346512906
# intersected
# epoch:  112 ,  step :  197 ,  avg_reward :  -0.6169149078203645
# crashed
# epoch:  113 ,  step :  262 ,  avg_reward :  -0.7057111154939019
# crashed
# epoch:  114 ,  step :  1518 ,  avg_reward :  -0.6564143966144219
# crashed
# epoch:  115 ,  step :  1956 ,  avg_reward :  -0.6791317628146258
# crashed
# epoch:  116 ,  step :  39 ,  avg_reward :  -0.6701485163182904
# crashed
# epoch:  117 ,  step :  36 ,  avg_reward :  -0.7476832374624212
# intersected
# epoch:  118 ,  step :  1025 ,  avg_reward :  -0.6321503826698727
# intersected
# epoch:  119 ,  step :  448 ,  avg_reward :  -0.737328206930283
# crashed
# epoch:  120 ,  step :  49 ,  avg_reward :  -0.5701879878681892
# crashed
# epoch:  121 ,  step :  37 ,  avg_reward :  -0.6771456113080436
# crashed
# epoch:  122 ,  step :  30 ,  avg_reward :  -0.7825604814471674
# crashed
# epoch:  123 ,  step :  30 ,  avg_reward :  -0.8004433280240288
# intersected
# epoch:  124 ,  step :  57 ,  avg_reward :  -0.49110366271238826
# intersected
# epoch:  125 ,  step :  838 ,  avg_reward :  -0.6759147756417647
# intersected
# epoch:  126 ,  step :  165 ,  avg_reward :  -0.6059412630866445
# crashed
# epoch:  127 ,  step :  33 ,  avg_reward :  -0.8568548606054811
# intersected
# epoch:  128 ,  step :  94 ,  avg_reward :  -0.4801316077023041
# crashed
# epoch:  129 ,  step :  738 ,  avg_reward :  -0.6324144142266579
# crashed
# epoch:  130 ,  step :  356 ,  avg_reward :  -0.7118032425395666
# intersected
# epoch:  131 ,  step :  389 ,  avg_reward :  -0.5786831725552256
# crashed
# epoch:  132 ,  step :  2460 ,  avg_reward :  -0.6380359885638031
# intersected
# epoch:  133 ,  step :  48 ,  avg_reward :  -0.7045342878943938
# crashed
# epoch:  134 ,  step :  400 ,  avg_reward :  -0.7307253199881627
# crashed
# epoch:  135 ,  step :  33 ,  avg_reward :  -0.678207746727993
# crashed
# epoch:  136 ,  step :  785 ,  avg_reward :  -0.5545717959925838
# crashed
# epoch:  137 ,  step :  32 ,  avg_reward :  -0.7782907191196873
# crashed
# epoch:  138 ,  step :  1160 ,  avg_reward :  -0.5045572909825908
# intersected
# epoch:  139 ,  step :  645 ,  avg_reward :  -0.5928406440125894
# intersected
# epoch:  140 ,  step :  40 ,  avg_reward :  -0.6138787791449273
# crashed
# epoch:  141 ,  step :  22 ,  avg_reward :  -0.9404698780528927
# crashed
# epoch:  142 ,  step :  30 ,  avg_reward :  -0.8164207325052449
# intersected
# epoch:  143 ,  step :  36 ,  avg_reward :  -0.6971245893189183
# intersected
# epoch:  144 ,  step :  36 ,  avg_reward :  -0.721043740169794
# intersected
# epoch:  145 ,  step :  39 ,  avg_reward :  -0.6577462410741338
# intersected
# epoch:  146 ,  step :  47 ,  avg_reward :  -0.61650634472283
# intersected
# epoch:  147 ,  step :  620 ,  avg_reward :  -0.6100248482385212
# crashed
# epoch:  148 ,  step :  36 ,  avg_reward :  -0.7526757974879235
# intersected
# epoch:  149 ,  step :  619 ,  avg_reward :  -0.6368238501105834
# intersected
# epoch:  150 ,  step :  36 ,  avg_reward :  -0.6973069635687433
# crashed
# epoch:  151 ,  step :  196 ,  avg_reward :  -0.627460300891501
# intersected
# epoch:  152 ,  step :  115 ,  avg_reward :  -0.5128355390573837
# intersected
# epoch:  153 ,  step :  139 ,  avg_reward :  -0.5248463693609082
# crashed
# epoch:  154 ,  step :  121 ,  avg_reward :  -0.6355590273264857
# intersected
# epoch:  155 ,  step :  202 ,  avg_reward :  -0.6838198657912695
# intersected
# epoch:  156 ,  step :  47 ,  avg_reward :  -0.6603644225697451
# intersected
# epoch:  157 ,  step :  45 ,  avg_reward :  -0.6429623077426374
# crashed
# epoch:  158 ,  step :  181 ,  avg_reward :  -0.5263202105888684
# intersected
# epoch:  159 ,  step :  134 ,  avg_reward :  -0.4461641190392084
# intersected
# epoch:  160 ,  step :  119 ,  avg_reward :  -0.5843311275048712
# intersected
# epoch:  161 ,  step :  1143 ,  avg_reward :  -0.6859004462683098
# intersected
# epoch:  162 ,  step :  301 ,  avg_reward :  -0.5881706142075956
# intersected
# epoch:  163 ,  step :  941 ,  avg_reward :  -0.6625046813849452
# crashed
# epoch:  164 ,  step :  840 ,  avg_reward :  -0.4729129409453785
# intersected
# epoch:  165 ,  step :  37 ,  avg_reward :  -0.6836990301958654
# crashed
# epoch:  166 ,  step :  34 ,  avg_reward :  -0.6909776812692918
# crashed
# epoch:  167 ,  step :  28 ,  avg_reward :  -0.8196085953386442
# crashed
# epoch:  168 ,  step :  23 ,  avg_reward :  -0.8830488311540279
# intersected
# epoch:  169 ,  step :  35 ,  avg_reward :  -0.6896797506390607
# intersected
# epoch:  170 ,  step :  35 ,  avg_reward :  -0.6746603738722984
# crashed
# epoch:  171 ,  step :  615 ,  avg_reward :  -0.5184334351127378
# crashed
# epoch:  172 ,  step :  475 ,  avg_reward :  -0.4327210345351795
# crashed
# epoch:  173 ,  step :  345 ,  avg_reward :  -0.431771425226634
# intersected
# epoch:  174 ,  step :  299 ,  avg_reward :  -0.5170797158779737
# intersected
# epoch:  175 ,  step :  36 ,  avg_reward :  -0.710305861978767
# intersected
# epoch:  176 ,  step :  33 ,  avg_reward :  -0.6765764905743018
# crashed
# epoch:  177 ,  step :  26 ,  avg_reward :  -0.8173990916931362
# crashed
# epoch:  178 ,  step :  40 ,  avg_reward :  -0.6519099322797546
# intersected
# epoch:  179 ,  step :  35 ,  avg_reward :  -0.6787441119472925
# crashed
# epoch:  180 ,  step :  296 ,  avg_reward :  -0.6191050961951156
# crashed
# epoch:  181 ,  step :  836 ,  avg_reward :  -0.4311405923448519
# crashed
# epoch:  182 ,  step :  41 ,  avg_reward :  -0.6151349879098613
# crashed
# epoch:  183 ,  step :  405 ,  avg_reward :  -0.5820371250422111
# intersected
# epoch:  184 ,  step :  152 ,  avg_reward :  -0.4107060222966742
# crashed
# epoch:  185 ,  step :  169 ,  avg_reward :  -0.3916737237809085
# crashed
# epoch:  186 ,  step :  41 ,  avg_reward :  -0.5885147212335337
# crashed
# epoch:  187 ,  step :  38 ,  avg_reward :  -0.6812152290921007
# crashed
# epoch:  188 ,  step :  29 ,  avg_reward :  -0.7281635504615557
# crashed
# epoch:  189 ,  step :  24 ,  avg_reward :  -0.8721913189978325
# intersected
# epoch:  190 ,  step :  37 ,  avg_reward :  -0.6885096313276674
# crashed
# epoch:  191 ,  step :  655 ,  avg_reward :  -0.4819338571501716
# intersected
# epoch:  192 ,  step :  39 ,  avg_reward :  -0.6633772033827295
# crashed
# epoch:  193 ,  step :  34 ,  avg_reward :  -0.6980229028428601
# crashed
# epoch:  194 ,  step :  27 ,  avg_reward :  -0.842424984966884
# crashed
# epoch:  195 ,  step :  25 ,  avg_reward :  -0.8782412840342796
# crashed
# epoch:  196 ,  step :  696 ,  avg_reward :  -0.6363068487657639
# crashed
# epoch:  197 ,  step :  35 ,  avg_reward :  -0.7128501814569224
# crashed
# epoch:  198 ,  step :  29 ,  avg_reward :  -0.8143025235459804
# crashed
# epoch:  199 ,  step :  26 ,  avg_reward :  -0.8768595270835022
# crashed
# epoch:  200 ,  step :  26 ,  avg_reward :  -0.8455820953971257
# intersected
# epoch:  201 ,  step :  35 ,  avg_reward :  -0.674867631101526
# intersected
# epoch:  202 ,  step :  34 ,  avg_reward :  -0.6949074415041112
# intersected
# epoch:  203 ,  step :  125 ,  avg_reward :  -0.37176947977330876
# intersected
# epoch:  204 ,  step :  36 ,  avg_reward :  -0.6933519245116835
# crashed
# epoch:  205 ,  step :  22 ,  avg_reward :  -0.921639672330825
# crashed
# epoch:  206 ,  step :  27 ,  avg_reward :  -0.8497125573673585
# crashed
# epoch:  207 ,  step :  33 ,  avg_reward :  -0.7274568470119629
# intersected
# epoch:  208 ,  step :  37 ,  avg_reward :  -0.6980521950269887
# intersected
# epoch:  209 ,  step :  39 ,  avg_reward :  -0.6382021680144438
# crashed
# epoch:  210 ,  step :  683 ,  avg_reward :  -0.5731068261472348
# intersected
# epoch:  211 ,  step :  47 ,  avg_reward :  -0.5827843111940949
# intersected
# epoch:  212 ,  step :  38 ,  avg_reward :  -0.659698975111136
# intersected
# epoch:  213 ,  step :  41 ,  avg_reward :  -0.6555672953366246
# crashed
# epoch:  214 ,  step :  340 ,  avg_reward :  -0.4275444988072955
# crashed
# epoch:  215 ,  step :  26 ,  avg_reward :  -0.8405092827031828
# crashed
# epoch:  216 ,  step :  23 ,  avg_reward :  -0.9051799005137657
# intersected
# epoch:  217 ,  step :  116 ,  avg_reward :  -0.38240383916189846
# intersected
# epoch:  218 ,  step :  38 ,  avg_reward :  -0.6431967350575287
# crashed
# epoch:  219 ,  step :  238 ,  avg_reward :  -0.46676843232718945
# crashed
# epoch:  220 ,  step :  285 ,  avg_reward :  -0.47727854358863375
# intersected
# epoch:  221 ,  step :  247 ,  avg_reward :  -0.37529400149334924
# intersected
# epoch:  222 ,  step :  490 ,  avg_reward :  -0.6231608192086044
# intersected
# epoch:  223 ,  step :  37 ,  avg_reward :  -0.7128732104533195
# intersected
# epoch:  224 ,  step :  35 ,  avg_reward :  -0.7180839586177246
# intersected
# epoch:  225 ,  step :  34 ,  avg_reward :  -0.7061187101873445
# crashed
# epoch:  226 ,  step :  33 ,  avg_reward :  -0.7228665764767925
# crashed
# epoch:  227 ,  step :  28 ,  avg_reward :  -0.8171558889079608
# crashed
# epoch:  228 ,  step :  24 ,  avg_reward :  -0.8713969023610201
# intersected
# epoch:  229 ,  step :  148 ,  avg_reward :  -0.4069748940969942
# intersected
# epoch:  230 ,  step :  35 ,  avg_reward :  -0.7289977666925227
# intersected
# epoch:  231 ,  step :  37 ,  avg_reward :  -0.6563709937305459
# intersected
# epoch:  232 ,  step :  33 ,  avg_reward :  -0.7156988447153466
# crashed
# epoch:  233 ,  step :  24 ,  avg_reward :  -0.9037466116584811
# crashed
# epoch:  234 ,  step :  27 ,  avg_reward :  -0.8258008069242011
# intersected
# epoch:  235 ,  step :  33 ,  avg_reward :  -0.7297567590919871
# intersected
# epoch:  236 ,  step :  33 ,  avg_reward :  -0.7208443076117852
# intersected
# epoch:  237 ,  step :  170 ,  avg_reward :  -0.3618503060043904
# intersected
# epoch:  238 ,  step :  48 ,  avg_reward :  -0.7418267212857831
# intersected
# epoch:  239 ,  step :  49 ,  avg_reward :  -0.6876419630101002
# crashed
# epoch:  240 ,  step :  57 ,  avg_reward :  -0.5518280251628718
# intersected
# epoch:  241 ,  step :  36 ,  avg_reward :  -0.7082528916973048
# crashed
# epoch:  242 ,  step :  32 ,  avg_reward :  -0.7670557309265397
# crashed
# epoch:  243 ,  step :  27 ,  avg_reward :  -0.8546063278423719
# crashed
# epoch:  244 ,  step :  26 ,  avg_reward :  -0.8588334763174614
# intersected
# epoch:  245 ,  step :  45 ,  avg_reward :  -0.585714835599908
# intersected
# epoch:  246 ,  step :  34 ,  avg_reward :  -0.7196021146329393
# intersected
# epoch:  247 ,  step :  161 ,  avg_reward :  -0.32681650796400713
# intersected
# epoch:  248 ,  step :  244 ,  avg_reward :  -0.668800149189215
# intersected
# epoch:  249 ,  step :  150 ,  avg_reward :  -1.0268906123979935
# crashed
# epoch:  250 ,  step :  58 ,  avg_reward :  -0.74238293679097
# crashed
# epoch:  251 ,  step :  35 ,  avg_reward :  -0.6782331495256168
# crashed
# epoch:  252 ,  step :  30 ,  avg_reward :  -0.7684986258109293
# crashed
# epoch:  253 ,  step :  25 ,  avg_reward :  -0.8421709462393
# intersected
# epoch:  254 ,  step :  34 ,  avg_reward :  -0.6831689939540548
# intersected
# epoch:  255 ,  step :  34 ,  avg_reward :  -0.6914065255402739
# intersected
# epoch:  256 ,  step :  44 ,  avg_reward :  -0.5952669186537052
# intersected
# epoch:  257 ,  step :  41 ,  avg_reward :  -0.6232535582475757
# intersected
# epoch:  258 ,  step :  35 ,  avg_reward :  -0.6936852164666032
# intersected
# epoch:  259 ,  step :  51 ,  avg_reward :  -0.548349620487615
# crashed
# epoch:  260 ,  step :  27 ,  avg_reward :  -0.862998644311631
# crashed
# epoch:  261 ,  step :  30 ,  avg_reward :  -0.8444400036658845
# intersected
# epoch:  262 ,  step :  159 ,  avg_reward :  -0.36099881014256413
# intersected
# epoch:  263 ,  step :  37 ,  avg_reward :  -0.6931525913918347
# intersected
# epoch:  264 ,  step :  42 ,  avg_reward :  -0.6357236963261319
# crashed
# epoch:  265 ,  step :  165 ,  avg_reward :  -0.36467578668275247
# intersected
# epoch:  266 ,  step :  37 ,  avg_reward :  -0.6933924472945461
# crashed
# epoch:  267 ,  step :  32 ,  avg_reward :  -0.7569956014938111
# crashed
# epoch:  268 ,  step :  26 ,  avg_reward :  -0.8623716794550517
# crashed
# epoch:  269 ,  step :  23 ,  avg_reward :  -0.9139061066747075
# intersected
# epoch:  270 ,  step :  34 ,  avg_reward :  -0.7099970526363582
# intersected
# epoch:  271 ,  step :  34 ,  avg_reward :  -0.7008464405194578
# intersected
# epoch:  272 ,  step :  36 ,  avg_reward :  -0.6865219446745905
# intersected
# epoch:  273 ,  step :  36 ,  avg_reward :  -0.6744218430395938
# intersected
# epoch:  274 ,  step :  38 ,  avg_reward :  -0.6886465108366696
# intersected
# epoch:  275 ,  step :  37 ,  avg_reward :  -0.6771377261093608
# intersected
# epoch:  276 ,  step :  33 ,  avg_reward :  -0.7016295176271484
# crashed
# epoch:  277 ,  step :  26 ,  avg_reward :  -0.8943866298009516
# intersected
# epoch:  278 ,  step :  35 ,  avg_reward :  -0.7003070187549374
# intersected
# epoch:  279 ,  step :  34 ,  avg_reward :  -0.6988682590608947
# intersected
# epoch:  280 ,  step :  36 ,  avg_reward :  -0.6835702886853084
# intersected
# epoch:  281 ,  step :  35 ,  avg_reward :  -0.6947279642026671
# intersected
# epoch:  282 ,  step :  40 ,  avg_reward :  -0.6657738556167709
# intersected
# epoch:  283 ,  step :  40 ,  avg_reward :  -0.6648112426390231
# intersected
# epoch:  284 ,  step :  43 ,  avg_reward :  -0.6547881562325077
# intersected
# epoch:  285 ,  step :  49 ,  avg_reward :  -0.6230448628942616
# crashed
# epoch:  286 ,  step :  101 ,  avg_reward :  -0.4750602219240935
# intersected
# epoch:  287 ,  step :  34 ,  avg_reward :  -0.7057354717822341
# crashed
# epoch:  288 ,  step :  31 ,  avg_reward :  -0.7601871646298591
# crashed
# epoch:  289 ,  step :  27 ,  avg_reward :  -0.8260484595364928
# crashed
# epoch:  290 ,  step :  23 ,  avg_reward :  -0.9080762701690367
# intersected
# epoch:  291 ,  step :  32 ,  avg_reward :  -0.7335610532221424
# intersected
# epoch:  292 ,  step :  127 ,  avg_reward :  -0.3601263963681963
# intersected
# epoch:  293 ,  step :  34 ,  avg_reward :  -0.7089366755806661
# intersected
# epoch:  294 ,  step :  34 ,  avg_reward :  -0.7134191185824559
# crashed
# epoch:  295 ,  step :  25 ,  avg_reward :  -0.8532187648535782
# crashed
# epoch:  296 ,  step :  26 ,  avg_reward :  -0.8566300232562637
# intersected
# epoch:  297 ,  step :  33 ,  avg_reward :  -0.6990580654113433
# intersected
# epoch:  298 ,  step :  35 ,  avg_reward :  -0.6834391082362881
# intersected
# epoch:  299 ,  step :  36 ,  avg_reward :  -0.7133416145821948
# intersected
# epoch:  300 ,  step :  37 ,  avg_reward :  -0.6873476686734804
# intersected
# epoch:  301 ,  step :  42 ,  avg_reward :  -0.6911383545810592
# intersected
# epoch:  302 ,  step :  853 ,  avg_reward :  -0.4119761831219555
# intersected
# epoch:  303 ,  step :  41 ,  avg_reward :  -0.706939576326744
# intersected
# epoch:  304 ,  step :  36 ,  avg_reward :  -0.7165417269074467
# intersected
# epoch:  305 ,  step :  35 ,  avg_reward :  -0.7273074502802452
# intersected
# epoch:  306 ,  step :  37 ,  avg_reward :  -0.7205504902392638
# intersected
# epoch:  307 ,  step :  34 ,  avg_reward :  -0.70881864675351
# intersected
# epoch:  308 ,  step :  35 ,  avg_reward :  -0.7046129237124077
# crashed
# epoch:  309 ,  step :  31 ,  avg_reward :  -0.7959806789659324
# crashed
# epoch:  310 ,  step :  27 ,  avg_reward :  -0.839735121834527
# crashed
# epoch:  311 ,  step :  25 ,  avg_reward :  -0.8744177009626373
# intersected
# epoch:  312 ,  step :  36 ,  avg_reward :  -0.7228215288100212
# intersected
# epoch:  313 ,  step :  38 ,  avg_reward :  -0.6753830639753976
# intersected
# epoch:  314 ,  step :  40 ,  avg_reward :  -0.6650633863135865
# intersected
# epoch:  315 ,  step :  44 ,  avg_reward :  -0.6080911142450239
# intersected
# epoch:  316 ,  step :  36 ,  avg_reward :  -0.7308807034687969
# intersected
# epoch:  317 ,  step :  37 ,  avg_reward :  -0.6973871587754775
# crashed
# epoch:  318 ,  step :  26 ,  avg_reward :  -0.8795377494130936
# intersected
# epoch:  319 ,  step :  37 ,  avg_reward :  -0.6598325810885063
# intersected
# epoch:  320 ,  step :  35 ,  avg_reward :  -0.7055976209374615
# intersected
# epoch:  321 ,  step :  35 ,  avg_reward :  -0.7224182156613722
# intersected
# epoch:  322 ,  step :  38 ,  avg_reward :  -0.6801030872645499
# intersected
# epoch:  323 ,  step :  47 ,  avg_reward :  -0.5897191499166402
# intersected
# epoch:  324 ,  step :  50 ,  avg_reward :  -0.6018850577221486
# intersected
# epoch:  325 ,  step :  40 ,  avg_reward :  -0.686468317493014
# intersected
# epoch:  326 ,  step :  38 ,  avg_reward :  -0.6802829442078554
# intersected
# epoch:  327 ,  step :  40 ,  avg_reward :  -0.6517013305816314
# intersected
# epoch:  328 ,  step :  39 ,  avg_reward :  -0.649039840747724
# intersected
# epoch:  329 ,  step :  36 ,  avg_reward :  -0.6982770546890362
# crashed
# epoch:  330 ,  step :  35 ,  avg_reward :  -0.7125865303675475
# crashed
# epoch:  331 ,  step :  32 ,  avg_reward :  -0.753685278480211
# crashed
# epoch:  332 ,  step :  27 ,  avg_reward :  -0.816386467642814
# intersected
# epoch:  333 ,  step :  129 ,  avg_reward :  -0.35012683288528984
# intersected
# epoch:  334 ,  step :  39 ,  avg_reward :  -0.6720356823624279
# intersected
# epoch:  335 ,  step :  37 ,  avg_reward :  -0.6714809499135089
# intersected
# epoch:  336 ,  step :  42 ,  avg_reward :  -0.6085008155960262
# crashed
# epoch:  337 ,  step :  25 ,  avg_reward :  -0.8946057908100683
# crashed
# epoch:  338 ,  step :  89 ,  avg_reward :  -0.46188448884585687
# intersected
# epoch:  339 ,  step :  37 ,  avg_reward :  -0.6473411896780292
# intersected
# epoch:  340 ,  step :  38 ,  avg_reward :  -0.6567097837508211
# crashed
# epoch:  341 ,  step :  244 ,  avg_reward :  -0.38668954208673545
# crashed
# epoch:  342 ,  step :  39 ,  avg_reward :  -0.6691471556157018
# crashed
# epoch:  343 ,  step :  31 ,  avg_reward :  -0.7757280640641642
# crashed
# epoch:  344 ,  step :  28 ,  avg_reward :  -0.8363709673590692
# crashed
# epoch:  345 ,  step :  24 ,  avg_reward :  -0.897986361134144
# intersected
# epoch:  346 ,  step :  37 ,  avg_reward :  -0.6862507638434583
# crashed
# epoch:  347 ,  step :  303 ,  avg_reward :  -0.36611323554461367
# intersected
# epoch:  348 ,  step :  144 ,  avg_reward :  -0.373484993757055
# crashed
# epoch:  349 ,  step :  227 ,  avg_reward :  -0.5511506939488064
# crashed
# epoch:  350 ,  step :  34 ,  avg_reward :  -0.7339033243435377
# crashed
# epoch:  351 ,  step :  28 ,  avg_reward :  -0.8317840845330711
# intersected
# epoch:  352 ,  step :  37 ,  avg_reward :  -0.6807185315473757
# intersected
# epoch:  353 ,  step :  35 ,  avg_reward :  -0.7004464951222951
# intersected
# epoch:  354 ,  step :  35 ,  avg_reward :  -0.7071417209703109
# intersected
# epoch:  355 ,  step :  35 ,  avg_reward :  -0.6929408490068661
# intersected
# epoch:  356 ,  step :  35 ,  avg_reward :  -0.7344309748885173
# intersected
# epoch:  357 ,  step :  35 ,  avg_reward :  -0.7137752920049056
# intersected
# epoch:  358 ,  step :  35 ,  avg_reward :  -0.7045756065385598
# intersected
# epoch:  359 ,  step :  36 ,  avg_reward :  -0.6946463501694777
# crashed
# epoch:  360 ,  step :  24 ,  avg_reward :  -0.9004675430774044
# crashed
# epoch:  361 ,  step :  30 ,  avg_reward :  -0.7974252414345943
# intersected
# epoch:  362 ,  step :  34 ,  avg_reward :  -0.7221546357871987
# intersected
# epoch:  363 ,  step :  37 ,  avg_reward :  -0.7163213808748938
# intersected
# epoch:  364 ,  step :  36 ,  avg_reward :  -0.6959581689048232
# intersected
# epoch:  365 ,  step :  36 ,  avg_reward :  -0.690987786740976
# intersected
# epoch:  366 ,  step :  42 ,  avg_reward :  -0.6375740146851305
# intersected
# epoch:  367 ,  step :  454 ,  avg_reward :  -0.40242260909241756
# intersected
# epoch:  368 ,  step :  36 ,  avg_reward :  -0.6984532922692752
# intersected
# epoch:  369 ,  step :  37 ,  avg_reward :  -0.7052731151101566
# crashed
# epoch:  370 ,  step :  111 ,  avg_reward :  -0.403390264478111
# intersected
# epoch:  371 ,  step :  34 ,  avg_reward :  -0.7158967029896859
# intersected
# epoch:  372 ,  step :  35 ,  avg_reward :  -0.7167759729482795
# intersected
# epoch:  373 ,  step :  35 ,  avg_reward :  -0.7132246713510783
# intersected
# epoch:  374 ,  step :  37 ,  avg_reward :  -0.6703734005931506
# intersected
# epoch:  375 ,  step :  332 ,  avg_reward :  -0.40961542162819176
# intersected
# epoch:  376 ,  step :  34 ,  avg_reward :  -0.7056478436078822
# intersected
# epoch:  377 ,  step :  36 ,  avg_reward :  -0.7068293311052893
# intersected
# epoch:  378 ,  step :  35 ,  avg_reward :  -0.7093779448994336
# intersected
# epoch:  379 ,  step :  36 ,  avg_reward :  -0.6898526843229259
# intersected
# epoch:  380 ,  step :  37 ,  avg_reward :  -0.7319528412539154
# intersected
# epoch:  381 ,  step :  36 ,  avg_reward :  -0.7010813366326661
# intersected
# epoch:  382 ,  step :  35 ,  avg_reward :  -0.703669919927505
# crashed
# epoch:  383 ,  step :  24 ,  avg_reward :  -0.9243232786481591
# crashed
# epoch:  384 ,  step :  28 ,  avg_reward :  -0.8276671557205798
# intersected
# epoch:  385 ,  step :  111 ,  avg_reward :  -0.43778776135527614
# intersected
# epoch:  386 ,  step :  37 ,  avg_reward :  -0.6896064447364953
# crashed
# epoch:  387 ,  step :  1069 ,  avg_reward :  -0.41340943254642226
# crashed
# epoch:  388 ,  step :  34 ,  avg_reward :  -0.7122706961183942
# crashed
# epoch:  389 ,  step :  27 ,  avg_reward :  -0.8418234103412578
# crashed
# epoch:  390 ,  step :  27 ,  avg_reward :  -0.8442255920141609
# intersected
# epoch:  391 ,  step :  37 ,  avg_reward :  -0.6863721568388746
# intersected
# epoch:  392 ,  step :  35 ,  avg_reward :  -0.6876316928733538
# intersected
# epoch:  393 ,  step :  35 ,  avg_reward :  -0.7159500540147722
# crashed
# epoch:  394 ,  step :  548 ,  avg_reward :  -0.5016223461715087
# crashed
# epoch:  395 ,  step :  50 ,  avg_reward :  -0.6775437275837297
# crashed
# epoch:  396 ,  step :  41 ,  avg_reward :  -0.7030955077882947
# crashed
# epoch:  397 ,  step :  33 ,  avg_reward :  -0.7749508031367175
# crashed
# epoch:  398 ,  step :  25 ,  avg_reward :  -0.8777416310182139
# intersected
# epoch:  399 ,  step :  35 ,  avg_reward :  -0.691700788722613
# intersected
# epoch:  400 ,  step :  37 ,  avg_reward :  -0.7108800765491787
# intersected
# epoch:  401 ,  step :  35 ,  avg_reward :  -0.685529002182249
# intersected
# epoch:  402 ,  step :  35 ,  avg_reward :  -0.6910783711979686
# intersected
# epoch:  403 ,  step :  35 ,  avg_reward :  -0.6847122438917458
# intersected
# epoch:  404 ,  step :  34 ,  avg_reward :  -0.7077296057670097
# intersected
# epoch:  405 ,  step :  33 ,  avg_reward :  -0.7163073468353662
# crashed
# epoch:  406 ,  step :  26 ,  avg_reward :  -0.8404001609620769
# intersected
# epoch:  407 ,  step :  38 ,  avg_reward :  -0.6362968832239646
# intersected
# epoch:  408 ,  step :  34 ,  avg_reward :  -0.7044171954480163
# intersected
# epoch:  409 ,  step :  35 ,  avg_reward :  -0.6724628644455606
# crashed
# epoch:  410 ,  step :  354 ,  avg_reward :  -0.631852852302832
# crashed
# epoch:  411 ,  step :  32 ,  avg_reward :  -0.7602056944257106
# crashed
# epoch:  412 ,  step :  380 ,  avg_reward :  -0.42150286059903497
# intersected
# epoch:  413 ,  step :  36 ,  avg_reward :  -0.7204234783415819
# intersected
# epoch:  414 ,  step :  37 ,  avg_reward :  -0.7021014005176135
# crashed
# epoch:  415 ,  step :  299 ,  avg_reward :  -0.5242267041024734
# crashed
# epoch:  416 ,  step :  32 ,  avg_reward :  -0.7618266069598174
# crashed
# epoch:  417 ,  step :  29 ,  avg_reward :  -0.8292962707992685
# crashed
# epoch:  418 ,  step :  24 ,  avg_reward :  -0.8940853007053193
# intersected
# epoch:  419 ,  step :  36 ,  avg_reward :  -0.691881409037666
# crashed
# epoch:  420 ,  step :  302 ,  avg_reward :  -0.4228065916943407
# intersected
# epoch:  421 ,  step :  206 ,  avg_reward :  -0.3818097157288018
# crashed
# epoch:  422 ,  step :  123 ,  avg_reward :  -0.6327910881333637
# crashed
# epoch:  423 ,  step :  41 ,  avg_reward :  -0.6824670612376162
# crashed
# epoch:  424 ,  step :  35 ,  avg_reward :  -0.7617451896532854
# crashed
# epoch:  425 ,  step :  34 ,  avg_reward :  -0.7487893451951855
# crashed
# epoch:  426 ,  step :  378 ,  avg_reward :  -0.37601974693920914
# intersected
# epoch:  427 ,  step :  36 ,  avg_reward :  -0.6979642133026768
# intersected
# epoch:  428 ,  step :  35 ,  avg_reward :  -0.7097156795982585
# crashed
# epoch:  429 ,  step :  769 ,  avg_reward :  -0.5908246482195756
# crashed
# epoch:  430 ,  step :  330 ,  avg_reward :  -0.48146515951607294
# crashed
# epoch:  431 ,  step :  31 ,  avg_reward :  -0.78262307776787
# crashed
# epoch:  432 ,  step :  27 ,  avg_reward :  -0.8490235638908049
# crashed
# epoch:  433 ,  step :  27 ,  avg_reward :  -0.8608363567721535
# intersected
# epoch:  434 ,  step :  36 ,  avg_reward :  -0.7021298628636443
# intersected
# epoch:  435 ,  step :  35 ,  avg_reward :  -0.7040439031550911
# intersected
# epoch:  436 ,  step :  36 ,  avg_reward :  -0.7087685527162269
# crashed
# epoch:  437 ,  step :  207 ,  avg_reward :  -0.497084798938982
# crashed
# epoch:  438 ,  step :  38 ,  avg_reward :  -0.6749465224380098
# crashed
# epoch:  439 ,  step :  351 ,  avg_reward :  -0.4123681646237603
# crashed
# epoch:  440 ,  step :  33 ,  avg_reward :  -0.7400774845333329
# crashed
# epoch:  441 ,  step :  29 ,  avg_reward :  -0.8115001625524974
# crashed
# epoch:  442 ,  step :  26 ,  avg_reward :  -0.8616499165575042
# intersected
# epoch:  443 ,  step :  35 ,  avg_reward :  -0.6970894484750791
# intersected
# epoch:  444 ,  step :  35 ,  avg_reward :  -0.7073675143484538
# intersected
# epoch:  445 ,  step :  35 ,  avg_reward :  -0.708613318855908
# intersected
# epoch:  446 ,  step :  36 ,  avg_reward :  -0.7180090015451989
# intersected
# epoch:  447 ,  step :  35 ,  avg_reward :  -0.7137721931361468
# intersected
# epoch:  448 ,  step :  37 ,  avg_reward :  -0.6938319310182667
# intersected
# epoch:  449 ,  step :  37 ,  avg_reward :  -0.6706237221942911
# crashed
# epoch:  450 ,  step :  25 ,  avg_reward :  -0.8992445356509166
# crashed
# epoch:  451 ,  step :  27 ,  avg_reward :  -0.8547925241676807
# intersected
# epoch:  452 ,  step :  656 ,  avg_reward :  -0.6130298970540808
# intersected
# epoch:  453 ,  step :  35 ,  avg_reward :  -0.6930964659661188
# intersected
# epoch:  454 ,  step :  43 ,  avg_reward :  -0.5965727707619846
# crashed
# epoch:  455 ,  step :  25 ,  avg_reward :  -0.8877011197347987
# crashed
# epoch:  456 ,  step :  25 ,  avg_reward :  -0.8884940366436723
# intersected
# epoch:  457 ,  step :  402 ,  avg_reward :  -0.5431309715500459
# intersected
# epoch:  458 ,  step :  34 ,  avg_reward :  -0.708757367955286
# crashed
# epoch:  459 ,  step :  34 ,  avg_reward :  -0.7211514648947954
# crashed
# epoch:  460 ,  step :  28 ,  avg_reward :  -0.834204426182332
# crashed
# epoch:  461 ,  step :  26 ,  avg_reward :  -0.8579056138330472
# intersected
# epoch:  462 ,  step :  34 ,  avg_reward :  -0.7184244887994504
# intersected
# epoch:  463 ,  step :  35 ,  avg_reward :  -0.7088301560905648
# intersected
# epoch:  464 ,  step :  36 ,  avg_reward :  -0.6971511553903968
# intersected
# epoch:  465 ,  step :  37 ,  avg_reward :  -0.6984908855114971
# intersected
# epoch:  466 ,  step :  36 ,  avg_reward :  -0.6985887621774441
# intersected
# epoch:  467 ,  step :  35 ,  avg_reward :  -0.7124432903052099
# intersected
# epoch:  468 ,  step :  38 ,  avg_reward :  -0.6608969231880121
# crashed
# epoch:  469 ,  step :  25 ,  avg_reward :  -0.8846593411589779
# intersected
# epoch:  470 ,  step :  305 ,  avg_reward :  -0.5896504353914778
# intersected
# epoch:  471 ,  step :  36 ,  avg_reward :  -0.6880336066611031
# intersected
# epoch:  472 ,  step :  36 ,  avg_reward :  -0.6951433496032634
# intersected
# epoch:  473 ,  step :  36 ,  avg_reward :  -0.6966353637395647
# intersected
# epoch:  474 ,  step :  35 ,  avg_reward :  -0.7005773573181556
# crashed
# epoch:  475 ,  step :  32 ,  avg_reward :  -0.7892348474602624
# crashed
# epoch:  476 ,  step :  27 ,  avg_reward :  -0.850493537729247
# crashed
# epoch:  477 ,  step :  25 ,  avg_reward :  -0.8919227265435878
# intersected
# epoch:  478 ,  step :  35 ,  avg_reward :  -0.7177795476738487
# intersected
# epoch:  479 ,  step :  37 ,  avg_reward :  -0.6727563433664134
# intersected
# epoch:  480 ,  step :  42 ,  avg_reward :  -0.6183701160584301
# intersected
# epoch:  481 ,  step :  330 ,  avg_reward :  -0.4742817701208089
# crashed
# epoch:  482 ,  step :  256 ,  avg_reward :  -0.45901498868282037
# crashed
# epoch:  483 ,  step :  34 ,  avg_reward :  -0.7201565917733488
# crashed
# epoch:  484 ,  step :  30 ,  avg_reward :  -0.7973850995284935
# crashed
# epoch:  485 ,  step :  29 ,  avg_reward :  -0.8144246530699932
# intersected
# epoch:  486 ,  step :  36 ,  avg_reward :  -0.6884484619778072
# intersected
# epoch:  487 ,  step :  36 ,  avg_reward :  -0.6809396155463214
# intersected
# epoch:  488 ,  step :  36 ,  avg_reward :  -0.687584693441537
# intersected
# epoch:  489 ,  step :  39 ,  avg_reward :  -0.6487845768490559
# intersected
# epoch:  490 ,  step :  35 ,  avg_reward :  -0.7133956613224129
# intersected
# epoch:  491 ,  step :  35 ,  avg_reward :  -0.7052883233501752
# intersected
# epoch:  492 ,  step :  35 ,  avg_reward :  -0.7006711388892574
# crashed
# epoch:  493 ,  step :  25 ,  avg_reward :  -0.8903567341337932
# crashed
# epoch:  494 ,  step :  28 ,  avg_reward :  -0.8378941232842775
# crashed
# epoch:  495 ,  step :  385 ,  avg_reward :  -0.42935507107635346
# crashed
# epoch:  496 ,  step :  40 ,  avg_reward :  -0.6572827261092702
# crashed
# epoch:  497 ,  step :  33 ,  avg_reward :  -0.7507441426840352
# crashed
# epoch:  498 ,  step :  26 ,  avg_reward :  -0.8504826564381792
# crashed
# epoch:  499 ,  step :  26 ,  avg_reward :  -0.8577310980930671
# intersected
# epoch:  500 ,  step :  37 ,  avg_reward :  -0.6761792664992324
# intersected
# epoch:  501 ,  step :  35 ,  avg_reward :  -0.7071908833981897
# intersected
# epoch:  502 ,  step :  37 ,  avg_reward :  -0.6895258775552376
# intersected
# epoch:  503 ,  step :  37 ,  avg_reward :  -0.6951412764502657
# intersected
# epoch:  504 ,  step :  35 ,  avg_reward :  -0.7096960880209393
# intersected
# epoch:  505 ,  step :  36 ,  avg_reward :  -0.7082340829690069
# crashed
# epoch:  506 ,  step :  27 ,  avg_reward :  -0.8611301248863842
# crashed
# epoch:  507 ,  step :  25 ,  avg_reward :  -0.8950663492304558
# crashed
# epoch:  508 ,  step :  32 ,  avg_reward :  -0.7840755698452521
# intersected
# epoch:  509 ,  step :  114 ,  avg_reward :  -0.3685657681476256
# intersected
# epoch:  510 ,  step :  460 ,  avg_reward :  -0.5163493964899873
# intersected
# epoch:  511 ,  step :  37 ,  avg_reward :  -0.6752610043336661
# intersected
# epoch:  512 ,  step :  35 ,  avg_reward :  -0.7068480719484884
# intersected
# epoch:  513 ,  step :  35 ,  avg_reward :  -0.6985252158715523
# intersected
# epoch:  514 ,  step :  35 ,  avg_reward :  -0.6976741446268637
# intersected
# epoch:  515 ,  step :  34 ,  avg_reward :  -0.7077026727066744
# crashed
# epoch:  516 ,  step :  27 ,  avg_reward :  -0.8452040532830637
# intersected
# epoch:  517 ,  step :  37 ,  avg_reward :  -0.6667633122905681
# intersected
# epoch:  518 ,  step :  36 ,  avg_reward :  -0.6711385073044898
# intersected
# epoch:  519 ,  step :  108 ,  avg_reward :  -0.39966419404545106
# intersected
# epoch:  520 ,  step :  337 ,  avg_reward :  -0.42201053573562586
# intersected
# epoch:  521 ,  step :  38 ,  avg_reward :  -0.6564115521527568
# intersected
# epoch:  522 ,  step :  36 ,  avg_reward :  -0.6824458879360171
# intersected
# epoch:  523 ,  step :  501 ,  avg_reward :  -0.5234522002950974
# crashed
# epoch:  524 ,  step :  128 ,  avg_reward :  -0.6481261496726876
# crashed
# epoch:  525 ,  step :  34 ,  avg_reward :  -0.7699489607277974
# crashed
# epoch:  526 ,  step :  31 ,  avg_reward :  -0.7899481897652241
# crashed
# epoch:  527 ,  step :  29 ,  avg_reward :  -0.8176976398708247
# crashed
# intersected
# epoch:  528 ,  step :  311 ,  avg_reward :  -0.5594335975042276
# intersected
# epoch:  529 ,  step :  305 ,  avg_reward :  -0.5110577493197657
# intersected
# epoch:  530 ,  step :  36 ,  avg_reward :  -0.6959364787329269
# intersected
# epoch:  531 ,  step :  36 ,  avg_reward :  -0.7057052717137793
# intersected
# epoch:  532 ,  step :  35 ,  avg_reward :  -0.7091336065099612
# crashed
# epoch:  533 ,  step :  33 ,  avg_reward :  -0.7449536912672119
# crashed
# epoch:  534 ,  step :  27 ,  avg_reward :  -0.8599236624668584
# crashed
# epoch:  535 ,  step :  26 ,  avg_reward :  -0.8828163762597823
# intersected
# epoch:  536 ,  step :  36 ,  avg_reward :  -0.6880950196529869
# intersected
# epoch:  537 ,  step :  35 ,  avg_reward :  -0.70703420261252
# intersected
# epoch:  538 ,  step :  36 ,  avg_reward :  -0.7024386639556908
# intersected
# epoch:  539 ,  step :  41 ,  avg_reward :  -0.6454229934240053
# intersected
# epoch:  540 ,  step :  128 ,  avg_reward :  -0.3538919113684852
# intersected
# epoch:  541 ,  step :  214 ,  avg_reward :  -0.5363599838892384
# intersected
# epoch:  542 ,  step :  427 ,  avg_reward :  -0.5393141308395524
# intersected
# epoch:  543 ,  step :  623 ,  avg_reward :  -0.44676752061362857
# crashed
# epoch:  544 ,  step :  29 ,  avg_reward :  -0.8178310222508496
# crashed
# epoch:  545 ,  step :  26 ,  avg_reward :  -0.870314199375893
# intersected
# epoch:  546 ,  step :  35 ,  avg_reward :  -0.6865547503061219
# intersected
# epoch:  547 ,  step :  35 ,  avg_reward :  -0.706387942866159
# crashed
# epoch:  548 ,  step :  261 ,  avg_reward :  -0.4847924601758829
# intersected
# epoch:  549 ,  step :  37 ,  avg_reward :  -0.6654564202593689
# intersected
# epoch:  550 ,  step :  35 ,  avg_reward :  -0.6971926415026463
# intersected
# epoch:  551 ,  step :  635 ,  avg_reward :  -0.4094374967816019
# intersected
# epoch:  552 ,  step :  36 ,  avg_reward :  -0.6970020221673205
# crashed
# epoch:  553 ,  step :  27 ,  avg_reward :  -0.845470010557663
# crashed
# epoch:  554 ,  step :  34 ,  avg_reward :  -0.7144151086059635
# intersected
# epoch:  555 ,  step :  34 ,  avg_reward :  -0.7042177523921298
# intersected
# epoch:  556 ,  step :  34 ,  avg_reward :  -0.7004340631705102
# intersected
# epoch:  557 ,  step :  42 ,  avg_reward :  -0.5925072970563139
# intersected
# epoch:  558 ,  step :  39 ,  avg_reward :  -0.6423936927570651
# crashed
# epoch:  559 ,  step :  239 ,  avg_reward :  -0.40812596330510836
# crashed
# epoch:  560 ,  step :  33 ,  avg_reward :  -0.7163183627620224
# crashed
# epoch:  561 ,  step :  28 ,  avg_reward :  -0.8138971944309793
# crashed
# epoch:  562 ,  step :  27 ,  avg_reward :  -0.8361497791392954
# intersected
# epoch:  563 ,  step :  35 ,  avg_reward :  -0.7003411169811972
# intersected
# epoch:  564 ,  step :  35 ,  avg_reward :  -0.6853255298604726
# intersected
# epoch:  565 ,  step :  34 ,  avg_reward :  -0.7020869702202336
# intersected
# epoch:  566 ,  step :  36 ,  avg_reward :  -0.6761899499875529
# intersected
# epoch:  567 ,  step :  34 ,  avg_reward :  -0.7075647693868353
# intersected
# epoch:  568 ,  step :  35 ,  avg_reward :  -0.7061057713221693
# intersected
# epoch:  569 ,  step :  36 ,  avg_reward :  -0.6848597020719338
# crashed
# epoch:  570 ,  step :  25 ,  avg_reward :  -0.8927532875457013
# crashed
# epoch:  571 ,  step :  28 ,  avg_reward :  -0.8230532822773482
# intersected
# epoch:  572 ,  step :  53 ,  avg_reward :  -0.5055319945761303
# intersected
# epoch:  573 ,  step :  35 ,  avg_reward :  -0.6790837969720249
# intersected
# epoch:  574 ,  step :  35 ,  avg_reward :  -0.6951497440061096
# crashed
# epoch:  575 ,  step :  303 ,  avg_reward :  -0.39382402694732566
# crashed
# epoch:  576 ,  step :  31 ,  avg_reward :  -0.7789465097504408
# crashed
# epoch:  577 ,  step :  30 ,  avg_reward :  -0.8139399003345169
# intersected
# epoch:  578 ,  step :  38 ,  avg_reward :  -0.6711727128469954
# intersected
# epoch:  579 ,  step :  36 ,  avg_reward :  -0.6903982185372338
# intersected
# epoch:  580 ,  step :  37 ,  avg_reward :  -0.6721839831732324
# intersected
# epoch:  581 ,  step :  408 ,  avg_reward :  -0.45238180678307416
# intersected
# epoch:  582 ,  step :  372 ,  avg_reward :  -0.5407077145291515
# intersected
# epoch:  583 ,  step :  528 ,  avg_reward :  -0.3897995005616172
# intersected
# epoch:  584 ,  step :  300 ,  avg_reward :  -0.5104022986899336
# intersected
# epoch:  585 ,  step :  90 ,  avg_reward :  -0.5973707040580782
# intersected
# epoch:  586 ,  step :  37 ,  avg_reward :  -0.6823013301574022
# intersected
# epoch:  587 ,  step :  39 ,  avg_reward :  -0.6943490271242068
# crashed
# epoch:  588 ,  step :  29 ,  avg_reward :  -0.8494966786113057
# intersected
# epoch:  589 ,  step :  206 ,  avg_reward :  -0.40066315666437535
# crashed
# epoch:  590 ,  step :  178 ,  avg_reward :  -0.7076261730176493
# crashed
# epoch:  591 ,  step :  39 ,  avg_reward :  -0.6687862412164922
# crashed
# epoch:  592 ,  step :  32 ,  avg_reward :  -0.7584505873393328
# crashed
# epoch:  593 ,  step :  28 ,  avg_reward :  -0.8324536944804148
# crashed
# epoch:  594 ,  step :  25 ,  avg_reward :  -0.8782872786152899
# intersected
# epoch:  595 ,  step :  37 ,  avg_reward :  -0.6813712212932841
# intersected
# epoch:  596 ,  step :  451 ,  avg_reward :  -0.3979097502925595
# crashed
# epoch:  597 ,  step :  220 ,  avg_reward :  -0.38643101103565153
# crashed
# epoch:  598 ,  step :  36 ,  avg_reward :  -0.691000240851868
# crashed
# epoch:  599 ,  step :  29 ,  avg_reward :  -0.8003096745129574
# crashed
# epoch:  600 ,  step :  28 ,  avg_reward :  -0.8216318783298876
# intersected
# epoch:  601 ,  step :  36 ,  avg_reward :  -0.6791768761517587
# intersected
# epoch:  602 ,  step :  36 ,  avg_reward :  -0.6734625467227431
# intersected
# epoch:  603 ,  step :  42 ,  avg_reward :  -0.6028082184385339
# crashed
# epoch:  604 ,  step :  208 ,  avg_reward :  -0.46444131815142103
# intersected
# epoch:  605 ,  step :  38 ,  avg_reward :  -0.6814511531106746
# intersected
# epoch:  606 ,  step :  37 ,  avg_reward :  -0.6768245349087978
# intersected
# epoch:  607 ,  step :  36 ,  avg_reward :  -0.6846510737170751
# intersected
# epoch:  608 ,  step :  37 ,  avg_reward :  -0.6718803306378969
# intersected
# epoch:  609 ,  step :  39 ,  avg_reward :  -0.6557558981346098
# intersected
# epoch:  610 ,  step :  47 ,  avg_reward :  -0.5756297504858252
# intersected
# epoch:  611 ,  step :  39 ,  avg_reward :  -0.6586252333813821
# intersected
# epoch:  612 ,  step :  37 ,  avg_reward :  -0.6900361531076139
# intersected
# epoch:  613 ,  step :  35 ,  avg_reward :  -0.7061561844012052
# intersected
# epoch:  614 ,  step :  35 ,  avg_reward :  -0.7063527788544306
# intersected
# epoch:  615 ,  step :  44 ,  avg_reward :  -0.5925490232014072
# crashed
# epoch:  616 ,  step :  28 ,  avg_reward :  -0.8389818627184614
# crashed
# epoch:  617 ,  step :  25 ,  avg_reward :  -0.8881003857608747
# intersected
# epoch:  618 ,  step :  38 ,  avg_reward :  -0.6601880907766334
# intersected
# epoch:  619 ,  step :  36 ,  avg_reward :  -0.6899053870596886
# intersected
# epoch:  620 ,  step :  36 ,  avg_reward :  -0.6924249672925998
# intersected
# epoch:  621 ,  step :  42 ,  avg_reward :  -0.6159910378271833
# intersected
# epoch:  622 ,  step :  327 ,  avg_reward :  -0.6005733146004372
# crashed
# epoch:  623 ,  step :  226 ,  avg_reward :  -0.43519663832405786
# crashed
# intersected
# epoch:  624 ,  step :  35 ,  avg_reward :  -0.6924347827790807
# crashed
# epoch:  625 ,  step :  30 ,  avg_reward :  -0.7789373346905485
# crashed
# epoch:  626 ,  step :  26 ,  avg_reward :  -0.8475113980048097
# crashed
# epoch:  627 ,  step :  25 ,  avg_reward :  -0.8897504947417356
# intersected
# epoch:  628 ,  step :  36 ,  avg_reward :  -0.6879572754401915
# crashed
# epoch:  629 ,  step :  233 ,  avg_reward :  -0.3651036658903666
# crashed
# epoch:  630 ,  step :  431 ,  avg_reward :  -0.42175521383261205
# crashed
# epoch:  631 ,  step :  32 ,  avg_reward :  -0.7599691835133635
# crashed
# epoch:  632 ,  step :  28 ,  avg_reward :  -0.8293586515877138
# crashed
# epoch:  633 ,  step :  26 ,  avg_reward :  -0.8628840969798861
# intersected
# epoch:  634 ,  step :  36 ,  avg_reward :  -0.6975434084825497
# intersected
# epoch:  635 ,  step :  35 ,  avg_reward :  -0.6974661025719399
# crashed
# epoch:  636 ,  step :  657 ,  avg_reward :  -0.39545651410321503
# crashed
# epoch:  637 ,  step :  31 ,  avg_reward :  -0.7864301223669975
# crashed
# epoch:  638 ,  step :  30 ,  avg_reward :  -0.7937015755450728
# intersected
# epoch:  639 ,  step :  36 ,  avg_reward :  -0.7017135148439115
# intersected
# epoch:  640 ,  step :  36 ,  avg_reward :  -0.708203353693258
# intersected
# epoch:  641 ,  step :  42 ,  avg_reward :  -0.6162465344268743
# crashed
# epoch:  642 ,  step :  219 ,  avg_reward :  -0.4446748240784065
# crashed
# intersected
# epoch:  643 ,  step :  38 ,  avg_reward :  -0.6646047027067015
# intersected
# epoch:  644 ,  step :  37 ,  avg_reward :  -0.6715692902532931
# intersected
# epoch:  645 ,  step :  36 ,  avg_reward :  -0.7007520821292803
# intersected
# epoch:  646 ,  step :  39 ,  avg_reward :  -0.6496930707715836
# intersected
# epoch:  647 ,  step :  36 ,  avg_reward :  -0.689606620685612
# crashed
# epoch:  648 ,  step :  189 ,  avg_reward :  -0.47488345728748815
# crashed
# epoch:  649 ,  step :  36 ,  avg_reward :  -0.7118696310844546
# crashed
# epoch:  650 ,  step :  30 ,  avg_reward :  -0.8053815878093838
# crashed
# epoch:  651 ,  step :  29 ,  avg_reward :  -0.8158538997938258
# intersected
# epoch:  652 ,  step :  37 ,  avg_reward :  -0.6854402020243572
# crashed
# epoch:  653 ,  step :  311 ,  avg_reward :  -0.38929931668009077
# intersected
# ...
# crashed
# epoch:  9790 ,  step :  391 ,  avg_reward :  -0.30972569467289945
# crashed
# epoch:  9791 ,  step :  32 ,  avg_reward :  -0.726360164521913
# crashed
# epoch:  9792 ,  step :  27 ,  avg_reward :  -0.8008373335648933
# crashed
# epoch:  9793 ,  step :  26 ,  avg_reward :  -0.8323881918438685
# crashed
# epoch:  9794 ,  step :  322 ,  avg_reward :  -0.3161895539226839
# intersected
# epoch:  9795 ,  step :  99 ,  avg_reward :  -0.3373299978381712
# crashed
# epoch:  9796 ,  step :  290 ,  avg_reward :  -0.30527820776321807
# crashed
# epoch:  9797 ,  step :  33 ,  avg_reward :  -0.702859654865641
# crashed
# epoch:  9798 ,  step :  27 ,  avg_reward :  -0.808535850839053
# crashed
# epoch:  9799 ,  step :  25 ,  avg_reward :  -0.8167449334127036
# crashed
# epoch:  9800 ,  step :  26 ,  avg_reward :  -0.813818413650514
# intersected
# epoch:  9801 ,  step :  35 ,  avg_reward :  -0.6564459460283382
# intersected
# epoch:  9802 ,  step :  33 ,  avg_reward :  -0.6962893345315475
# intersected
# epoch:  9803 ,  step :  33 ,  avg_reward :  -0.7006388356715564
# crashed
# epoch:  9804 ,  step :  191 ,  avg_reward :  -0.3349043514297225
# intersected
# epoch:  9805 ,  step :  32 ,  avg_reward :  -0.6727476445706986
# intersected
# epoch:  9806 ,  step :  34 ,  avg_reward :  -0.6676617938128033
# intersected
# epoch:  9807 ,  step :  198 ,  avg_reward :  -0.2889189986467421
# intersected
# epoch:  9808 ,  step :  36 ,  avg_reward :  -0.6790869461770612
# intersected
# epoch:  9809 ,  step :  34 ,  avg_reward :  -0.702277760906089
# intersected
# epoch:  9810 ,  step :  33 ,  avg_reward :  -0.7289819447886774
# intersected
# epoch:  9811 ,  step :  37 ,  avg_reward :  -0.6751219261160017
# crashed
# epoch:  9812 ,  step :  31 ,  avg_reward :  -0.7327480803849903
# crashed
# epoch:  9813 ,  step :  27 ,  avg_reward :  -0.8021935517026793
# crashed
# epoch:  9814 ,  step :  24 ,  avg_reward :  -0.8528002534235837
# crashed
# epoch:  9815 ,  step :  24 ,  avg_reward :  -0.8540970285959122
# intersected
# epoch:  9816 ,  step :  33 ,  avg_reward :  -0.7028962193929944
# intersected
# epoch:  9817 ,  step :  235 ,  avg_reward :  -0.3360774936076644
# crashed
# epoch:  9818 ,  step :  30 ,  avg_reward :  -0.7648157535045377
# intersected
# epoch:  9819 ,  step :  81 ,  avg_reward :  -0.38093354811411423
# intersected
# epoch:  9820 ,  step :  212 ,  avg_reward :  -0.2802023328366173
# crashed
# epoch:  9821 ,  step :  98 ,  avg_reward :  -0.3788725227432321
# intersected
# epoch:  9822 ,  step :  33 ,  avg_reward :  -0.6960558101050561
# crashed
# epoch:  9823 ,  step :  27 ,  avg_reward :  -0.8069519114241092
# crashed
# epoch:  9824 ,  step :  25 ,  avg_reward :  -0.8332938217203584
# crashed
# epoch:  9825 ,  step :  24 ,  avg_reward :  -0.8623097345063299
# intersected
# epoch:  9826 ,  step :  115 ,  avg_reward :  -0.3489796056021617
# crashed
# epoch:  9827 ,  step :  173 ,  avg_reward :  -0.2869356588579625
# crashed
# epoch:  9828 ,  step :  35 ,  avg_reward :  -0.6696562066203475
# intersected
# epoch:  9829 ,  step :  102 ,  avg_reward :  -0.3280020179674997
# crashed
# epoch:  9830 ,  step :  261 ,  avg_reward :  -0.32516476158803553
# intersected
# epoch:  9831 ,  step :  33 ,  avg_reward :  -0.7162057758957601
# crashed
# epoch:  9832 ,  step :  32 ,  avg_reward :  -0.7173531334623608
# crashed
# epoch:  9833 ,  step :  28 ,  avg_reward :  -0.782657611132968
# intersected
# epoch:  9834 ,  step :  34 ,  avg_reward :  -0.6912268268906384
# intersected
# epoch:  9835 ,  step :  231 ,  avg_reward :  -0.30223002575099134
# crashed
# epoch:  9836 ,  step :  25 ,  avg_reward :  -0.8291432928632946
# crashed
# epoch:  9837 ,  step :  26 ,  avg_reward :  -0.8174051257438618
# crashed
# epoch:  9838 ,  step :  35 ,  avg_reward :  -0.6638652672111258
# intersected
# epoch:  9839 ,  step :  32 ,  avg_reward :  -0.7269176042094028
# intersected
# epoch:  9840 ,  step :  177 ,  avg_reward :  -0.305585750137682
# intersected
# epoch:  9841 ,  step :  60 ,  avg_reward :  -0.4730452758681176
# intersected
# epoch:  9842 ,  step :  44 ,  avg_reward :  -0.5736603212666813
# intersected
# epoch:  9843 ,  step :  33 ,  avg_reward :  -0.7156348420605354
# intersected
# epoch:  9844 ,  step :  32 ,  avg_reward :  -0.7208578847807021
# crashed
# epoch:  9845 ,  step :  32 ,  avg_reward :  -0.7170667489618312
# crashed
# epoch:  9846 ,  step :  24 ,  avg_reward :  -0.8601669296308184
# crashed
# epoch:  9847 ,  step :  24 ,  avg_reward :  -0.8690704408165045
# intersected
# epoch:  9848 ,  step :  40 ,  avg_reward :  -0.5938110293437419
# intersected
# epoch:  9849 ,  step :  38 ,  avg_reward :  -0.6388113186640325
# intersected
# epoch:  9850 ,  step :  36 ,  avg_reward :  -0.660259605264123
# intersected
# epoch:  9851 ,  step :  34 ,  avg_reward :  -0.69525178054141
# intersected
# epoch:  9852 ,  step :  32 ,  avg_reward :  -0.7209996950844935
# intersected
# epoch:  9853 ,  step :  33 ,  avg_reward :  -0.7224031510592228
# intersected
# epoch:  9854 ,  step :  35 ,  avg_reward :  -0.6575458878336204
# crashed
# epoch:  9855 ,  step :  24 ,  avg_reward :  -0.8662876221085308
# crashed
# epoch:  9856 ,  step :  25 ,  avg_reward :  -0.848261398249044
# crashed
# epoch:  9857 ,  step :  31 ,  avg_reward :  -0.7219967719787015
# intersected
# epoch:  9858 ,  step :  33 ,  avg_reward :  -0.7039720369527287
# intersected
# epoch:  9859 ,  step :  33 ,  avg_reward :  -0.7087836602597006
# intersected
# epoch:  9860 ,  step :  34 ,  avg_reward :  -0.6898164505207621
# intersected
# epoch:  9861 ,  step :  33 ,  avg_reward :  -0.7070289687999565
# intersected
# epoch:  9862 ,  step :  33 ,  avg_reward :  -0.7020070978445833
# intersected
# epoch:  9863 ,  step :  35 ,  avg_reward :  -0.6770503041388611
# intersected
# epoch:  9864 ,  step :  33 ,  avg_reward :  -0.7020343982939631
# intersected
# epoch:  9865 ,  step :  32 ,  avg_reward :  -0.7206516984006754
# intersected
# epoch:  9866 ,  step :  32 ,  avg_reward :  -0.7165647347400936
# intersected
# epoch:  9867 ,  step :  340 ,  avg_reward :  -0.35662391833613205
# crashed
# epoch:  9868 ,  step :  145 ,  avg_reward :  -0.497844919630341
# crashed
# epoch:  9869 ,  step :  33 ,  avg_reward :  -0.6964072904857697
# intersected
# epoch:  9870 ,  step :  288 ,  avg_reward :  -0.24353662843283294
# intersected
# epoch:  9871 ,  step :  154 ,  avg_reward :  -0.46095430430171225
# crashed
# epoch:  9872 ,  step :  24 ,  avg_reward :  -0.8564551293294252
# intersected
# epoch:  9873 ,  step :  39 ,  avg_reward :  -0.609863966603305
# intersected
# epoch:  9874 ,  step :  143 ,  avg_reward :  -0.331460986185311
# intersected
# epoch:  9875 ,  step :  77 ,  avg_reward :  -0.41660253410625775
# crashed
# epoch:  9876 ,  step :  25 ,  avg_reward :  -0.8453097050979987
# crashed
# epoch:  9877 ,  step :  30 ,  avg_reward :  -0.7533568924243533
# crashed
# epoch:  9878 ,  step :  35 ,  avg_reward :  -0.6693868242172553
# crashed
# epoch:  9879 ,  step :  362 ,  avg_reward :  -0.3029313103073761
# crashed
# epoch:  9880 ,  step :  32 ,  avg_reward :  -0.7215811605192619
# crashed
# epoch:  9881 ,  step :  25 ,  avg_reward :  -0.8297392847771463
# crashed
# epoch:  9882 ,  step :  24 ,  avg_reward :  -0.8522143133401436
# crashed
# epoch:  9883 ,  step :  24 ,  avg_reward :  -0.8586154129062805
# intersected
# epoch:  9884 ,  step :  209 ,  avg_reward :  -0.31685215496377184
# intersected
# epoch:  9885 ,  step :  33 ,  avg_reward :  -0.6916373663231682
# crashed
# epoch:  9886 ,  step :  24 ,  avg_reward :  -0.8498455973074011
# crashed
# epoch:  9887 ,  step :  30 ,  avg_reward :  -0.7344513819348186
# intersected
# epoch:  9888 ,  step :  33 ,  avg_reward :  -0.6843902627115046
# intersected
# epoch:  9889 ,  step :  33 ,  avg_reward :  -0.7054302652559321
# intersected
# epoch:  9890 ,  step :  33 ,  avg_reward :  -0.6922630201779161
# crashed
# epoch:  9891 ,  step :  296 ,  avg_reward :  -0.3415578273414542
# crashed
# epoch:  9892 ,  step :  31 ,  avg_reward :  -0.756179446391931
# crashed
# epoch:  9893 ,  step :  27 ,  avg_reward :  -0.8098009772676606
# crashed
# epoch:  9894 ,  step :  26 ,  avg_reward :  -0.8238052544463144
# crashed
# epoch:  9895 ,  step :  24 ,  avg_reward :  -0.8742916516592848
# intersected
# epoch:  9896 ,  step :  32 ,  avg_reward :  -0.7253671273077404
# intersected
# epoch:  9897 ,  step :  34 ,  avg_reward :  -0.7151674401272637
# intersected
# epoch:  9898 ,  step :  35 ,  avg_reward :  -0.687890329922702
# intersected
# epoch:  9899 ,  step :  102 ,  avg_reward :  -0.3656157494138185
# intersected
# epoch:  9900 ,  step :  51 ,  avg_reward :  -0.48705187691541674
# crashed
# epoch:  9901 ,  step :  24 ,  avg_reward :  -0.8441886582796317
# crashed
# epoch:  9902 ,  step :  28 ,  avg_reward :  -0.7682060006045421
# crashed
# epoch:  9903 ,  step :  36 ,  avg_reward :  -0.6548609776936342
# intersected
# epoch:  9904 ,  step :  52 ,  avg_reward :  -0.49433800509372955
# intersected
# epoch:  9905 ,  step :  62 ,  avg_reward :  -0.46097513032451426
# intersected
# epoch:  9906 ,  step :  39 ,  avg_reward :  -0.6116246927984418
# intersected
# epoch:  9907 ,  step :  34 ,  avg_reward :  -0.6906827126655773
# intersected
# epoch:  9908 ,  step :  81 ,  avg_reward :  -0.3871383507221339
# crashed
# epoch:  9909 ,  step :  63 ,  avg_reward :  -0.4993699392986567
# intersected
# epoch:  9910 ,  step :  32 ,  avg_reward :  -0.6915604279555512
# crashed
# epoch:  9911 ,  step :  32 ,  avg_reward :  -0.7335380116121433
# crashed
# epoch:  9912 ,  step :  28 ,  avg_reward :  -0.7778745736025618
# crashed
# epoch:  9913 ,  step :  26 ,  avg_reward :  -0.8190272753683553
# intersected
# epoch:  9914 ,  step :  38 ,  avg_reward :  -0.6244971781185699
# intersected
# epoch:  9915 ,  step :  32 ,  avg_reward :  -0.7258523598865011
# intersected
# epoch:  9916 ,  step :  32 ,  avg_reward :  -0.7205281231002
# intersected
# epoch:  9917 ,  step :  32 ,  avg_reward :  -0.7028595312486795
# intersected
# epoch:  9918 ,  step :  35 ,  avg_reward :  -0.6676617308331386
# intersected
# epoch:  9919 ,  step :  34 ,  avg_reward :  -0.6865140931321438
# intersected
# epoch:  9920 ,  step :  42 ,  avg_reward :  -0.5771155207024445
# crashed
# epoch:  9921 ,  step :  25 ,  avg_reward :  -0.8299198432879948
# crashed
# epoch:  9922 ,  step :  25 ,  avg_reward :  -0.8311601139505812
# crashed
# epoch:  9923 ,  step :  31 ,  avg_reward :  -0.7286660042392293
# intersected
# epoch:  9924 ,  step :  32 ,  avg_reward :  -0.7105692607932867
# intersected
# epoch:  9925 ,  step :  48 ,  avg_reward :  -0.5257773769354203
# intersected
# epoch:  9926 ,  step :  34 ,  avg_reward :  -0.6787063181149973
# intersected
# epoch:  9927 ,  step :  41 ,  avg_reward :  -0.5855321738872404
# intersected
# epoch:  9928 ,  step :  41 ,  avg_reward :  -0.5851398782019116
# intersected
# epoch:  9929 ,  step :  100 ,  avg_reward :  -0.3783916832619089
# crashed
# epoch:  9930 ,  step :  85 ,  avg_reward :  -0.5899319928666371
# crashed
# epoch:  9931 ,  step :  35 ,  avg_reward :  -0.7156725746863776
# crashed
# epoch:  9932 ,  step :  25 ,  avg_reward :  -0.8084889278992741
# intersected
# epoch:  9933 ,  step :  124 ,  avg_reward :  -0.37023242797486483
# intersected
# epoch:  9934 ,  step :  128 ,  avg_reward :  -0.34817571885770343
# intersected
# epoch:  9935 ,  step :  68 ,  avg_reward :  -0.44962420750354937
# crashed
# epoch:  9936 ,  step :  31 ,  avg_reward :  -0.7279199234422041
# intersected
# epoch:  9937 ,  step :  46 ,  avg_reward :  -0.546339610995612
# intersected
# epoch:  9938 ,  step :  39 ,  avg_reward :  -0.5795215016404374
# intersected
# epoch:  9939 ,  step :  112 ,  avg_reward :  -0.3895215738853802
# intersected
# epoch:  9940 ,  step :  41 ,  avg_reward :  -0.6144004649516833
# intersected
# epoch:  9941 ,  step :  63 ,  avg_reward :  -0.43579909577650855
# intersected
# epoch:  9942 ,  step :  33 ,  avg_reward :  -0.6725891462254849
# intersected
# epoch:  9943 ,  step :  32 ,  avg_reward :  -0.724765309153397
# intersected
# epoch:  9944 ,  step :  32 ,  avg_reward :  -0.7312416813995686
# crashed
# epoch:  9945 ,  step :  31 ,  avg_reward :  -0.7505455227565501
# intersected
# epoch:  9946 ,  step :  32 ,  avg_reward :  -0.6849604966173589
# intersected
# epoch:  9947 ,  step :  33 ,  avg_reward :  -0.6547440278913753
# intersected
# epoch:  9948 ,  step :  32 ,  avg_reward :  -0.6933169938408659
# intersected
# epoch:  9949 ,  step :  32 ,  avg_reward :  -0.7330665094409173
# intersected
# epoch:  9950 ,  step :  32 ,  avg_reward :  -0.7218238617383697
# intersected
# epoch:  9951 ,  step :  63 ,  avg_reward :  -0.43721423520700003
# intersected
# epoch:  9952 ,  step :  34 ,  avg_reward :  -0.6798372739070331
# intersected
# epoch:  9953 ,  step :  45 ,  avg_reward :  -0.5453908007916043
# crashed
# epoch:  9954 ,  step :  24 ,  avg_reward :  -0.8527087607750138
# crashed
# epoch:  9955 ,  step :  26 ,  avg_reward :  -0.8155222830883625
# crashed
# intersected
# epoch:  9956 ,  step :  32 ,  avg_reward :  -0.7011781593725104
# intersected
# epoch:  9957 ,  step :  33 ,  avg_reward :  -0.7013366879314993
# intersected
# epoch:  9958 ,  step :  32 ,  avg_reward :  -0.7276920035013201
# intersected
# epoch:  9959 ,  step :  35 ,  avg_reward :  -0.6807803980365522
# intersected
# epoch:  9960 ,  step :  35 ,  avg_reward :  -0.6836559427811129
# intersected
# epoch:  9961 ,  step :  33 ,  avg_reward :  -0.7104520548073984
# intersected
# epoch:  9962 ,  step :  34 ,  avg_reward :  -0.6958927257961068
# crashed
# epoch:  9963 ,  step :  181 ,  avg_reward :  -0.32302577756625317
# crashed
# epoch:  9964 ,  step :  29 ,  avg_reward :  -0.7580366000859063
# crashed
# epoch:  9965 ,  step :  25 ,  avg_reward :  -0.8287865154004654
# crashed
# epoch:  9966 ,  step :  26 ,  avg_reward :  -0.8162959910080326
# intersected
# epoch:  9967 ,  step :  44 ,  avg_reward :  -0.5498153196039453
# intersected
# epoch:  9968 ,  step :  34 ,  avg_reward :  -0.7069040253714062
# intersected
# epoch:  9969 ,  step :  35 ,  avg_reward :  -0.7070979658686193
# intersected
# epoch:  9970 ,  step :  34 ,  avg_reward :  -0.7120669922371772
# intersected
# epoch:  9971 ,  step :  45 ,  avg_reward :  -0.5713159420621938
# intersected
# epoch:  9972 ,  step :  38 ,  avg_reward :  -0.652438813926838
# crashed
# epoch:  9973 ,  step :  25 ,  avg_reward :  -0.8351365318838654
# crashed
# epoch:  9974 ,  step :  25 ,  avg_reward :  -0.8203455952963377
# crashed
# epoch:  9975 ,  step :  26 ,  avg_reward :  -0.8076234599153028
# intersected
# epoch:  9976 ,  step :  34 ,  avg_reward :  -0.6695505247838536
# intersected
# epoch:  9977 ,  step :  52 ,  avg_reward :  -0.5105590103463752
# intersected
# epoch:  9978 ,  step :  45 ,  avg_reward :  -0.5714996110240355
# intersected
# epoch:  9979 ,  step :  33 ,  avg_reward :  -0.7215853542699189
# intersected
# epoch:  9980 ,  step :  230 ,  avg_reward :  -0.2924503215627483
# intersected
# epoch:  9981 ,  step :  32 ,  avg_reward :  -0.7286515598921673
# crashed
# epoch:  9982 ,  step :  28 ,  avg_reward :  -0.7754643695937131
# crashed
# epoch:  9983 ,  step :  26 ,  avg_reward :  -0.8175563962327115
# crashed
# epoch:  9984 ,  step :  24 ,  avg_reward :  -0.8555583775827383
# intersected
# epoch:  9985 ,  step :  34 ,  avg_reward :  -0.6799791322677171
# intersected
# epoch:  9986 ,  step :  34 ,  avg_reward :  -0.6902308873251058
# intersected
# epoch:  9987 ,  step :  34 ,  avg_reward :  -0.7098048855286268
# intersected
# epoch:  9988 ,  step :  36 ,  avg_reward :  -0.6854958141722576
# intersected
# epoch:  9989 ,  step :  47 ,  avg_reward :  -0.558360785004749
# intersected
# epoch:  9990 ,  step :  51 ,  avg_reward :  -0.5146788117334612
# crashed
# epoch:  9991 ,  step :  25 ,  avg_reward :  -0.843914414290993
# crashed
# epoch:  9992 ,  step :  26 ,  avg_reward :  -0.8152461834025796
# crashed
# epoch:  9993 ,  step :  29 ,  avg_reward :  -0.7621966120498388
# intersected
# epoch:  9994 ,  step :  33 ,  avg_reward :  -0.6927203682762114
# intersected
# epoch:  9995 ,  step :  50 ,  avg_reward :  -0.519256397427921
# intersected
# epoch:  9996 ,  step :  77 ,  avg_reward :  -0.3993126119275176
# intersected
# epoch:  9997 ,  step :  107 ,  avg_reward :  -0.3444480307577255
# intersected
# epoch:  9998 ,  step :  78 ,  avg_reward :  -0.40003157203068895
# intersected
# epoch:  9999 ,  step :  65 ,  avg_reward :  -0.43470128260989077
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
